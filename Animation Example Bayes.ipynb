# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss
from matplotlib.animation import FuncAnimation
from matplotlib import animation, rc
from IPython.display import HTML


class UpdateDist(object):
    def __init__(self, ax, prob=0.5):
        self.success = 0
        self.prob = prob
        self.line, = ax.plot([], [], 'k-')
        self.x = np.linspace(0, 1, 200)
        self.ax = ax

        # Set up plot parameters
        self.ax.set_xlim(0, 1)
        self.ax.set_ylim(0, 15)
        self.ax.grid(True)

        # This vertical line represents the theoretical value, to
        # which the plotted distribution should converge.
        self.ax.axvline(prob, linestyle='--', color='black')

    def init(self):
        self.success = 0
        self.line.set_data([], [])
        return self.line,

    def __call__(self, i):
        # This way the plot can continuously run and we just keep
        # watching new realizations of the process
        if i == 0:
            return self.init()

        # Choose success based on exceed a threshold with a uniform pick
        if np.random.rand(1,) < self.prob:
            self.success += 1
        y = ss.beta.pdf(self.x, self.success + 1, (i - self.success) + 1)
        self.line.set_data(self.x, y)
        return self.line,

fig, ax = plt.subplots()
ud = UpdateDist(ax, prob=0.7)
anim = FuncAnimation(fig, ud, frames=np.arange(300), init_func=ud.init,
                     interval=100, blit=True)
#HTML(anim.to_html5_video())
rc('animation', html='html5')
anim
#plt.show()
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
import importlib
#mod = importlib.import_module('sys')
tt = help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Anaconda2\lib\distutils\tests\__init__.py:18: ImportWarning: Not importing directory 'C:\Anaconda2\lib\lib-tk\test': missing __init__.py
#   from test.test_support import run_unittest
# C:\Anaconda2\lib\distutils\tests\__init__.py:18: ImportWarning: Not importing directory 'C:\Anaconda2\lib\site-packages\win32\test': missing __init__.py
#   from test.test_support import run_unittest
# C:\Anaconda2\lib\json\tests\__init__.py:7: ImportWarning: Not importing directory 'C:\Anaconda2\lib\lib-tk\test': missing __init__.py
#   from test import test_support
# C:\Anaconda2\lib\json\tests\__init__.py:7: ImportWarning: Not importing directory 'C:\Anaconda2\lib\site-packages\win32\test': missing __init__.py
#   from test import test_support
# BaseHTTPServer      cloudpickle         mkl                 spyder_breakpoints
# Bastion             clyent              mmap                spyder_io_dcm
# CGIHTTPServer       cmath               mmapfile            spyder_io_hdf5
# Canvas              cmd                 mmsystem            spyder_profiler
# ConfigParser        code                modulefinder        spyder_pylint
# Cookie              codecs              mpl_toolkits        sqlalchemy
# Crypto              codeop              mpmath              sqlite3
# Cython              collections         msgpack             sre
# Dialog              colorama            msilib              sre_compile
# DocXMLRPCServer     colorsys            msvcrt              sre_constants
# FileDialog          command             multifile           sre_parse
# FixTk               commands            multipledispatch    ssl
# HTMLParser          commctrl            multiprocessing     sspi
# IPython             compileall          mutex               sspicon
# MimeWriter          compiler            navigator_updater   stat
# OleFileIO_PL        comtypes            nbconvert           statsmodels
# OpenSSL             concurrent          nbformat            statvfs
# PIL                 conda               netbios             storemagic
# PyQt5               conda_env           netrc               string
# Queue               conf                networkx            stringold
# ScrolledText        configparser        new                 stringprep
# SimpleDialog        contextlib          nltk                strop
# SimpleHTTPServer    contextlib2         nntplib             struct
# SimpleXMLRPCServer  cookielib           nose                subprocess
# SocketServer        copy                notebook            subprocess32
# StringIO            copy_reg            nt                  sunau
# Tix                 cryptography        ntpath              sunaudio
# Tkconstants         csv                 ntsecuritycon       symbol
# Tkdnd               ctypes              nturl2path          sympy
# Tkinter             curl                numba               sympyprinting
# UserDict            curses              numbers             symtable
# UserList            cwp                 numexpr             sys
# UserString          cycler              numpy               sysconfig
# _LWPCookieJar       cython              numpydoc            tables
# _MozillaCookieJar   cythonmagic         odbc                tabnanny
# __builtin__         cytoolz             odo                 tarfile
# __future__          dask                olefile             tblib
# _abcoll             datashape           opcode              telnetlib
# _ast                datetime            openpyxl            tempfile
# _bisect             dateutil            operator            test_path
# _bsddb              dbhash              optparse            test_pycosat
# _cffi_backend       dbi                 os                  testpath
# _codecs             dde                 os2emxpath          tests
# _codecs_cn          decimal             packaging           textwrap
# _codecs_hk          decorator           pandas              this
# _codecs_iso2022     difflib             pandocfilters       thread
# _codecs_jp          dircache            parser              threading
# _codecs_kr          dis                 partd               time
# _codecs_tw          distributed         path                timeit
# _collections        distutils           pathlib2            timer
# _csv                doctest             patsy               tkColorChooser
# _ctypes             docutils            pdb                 tkCommonDialog
# _ctypes_test        dplython            pep8                tkFileDialog
# _elementtree        dumbdbm             perfmon             tkFont
# _functools          dummy_thread        pickle              tkMessageBox
# _hashlib            dummy_threading     pickleshare         tkSimpleDialog
# _heapq              easy_install        pickletools         tlz
# _hotshot            email               pip                 toaiff
# _io                 encodings           pipes               token
# _json               entrypoints         pkg_resources       tokenize
# _license            enum                pkgutil             toolz
# _locale             errno               platform            tornado
# _lsprof             et_xmlfile          plistlib            trace
# _md5                exceptions          ply                 traceback
# _msi                extern              popen2              traitlets
# _multibytecodec     fastcache           poplib              ttk
# _multiprocessing    filecmp             posixfile           tty
# _nsis               fileinput           posixpath           turtle
# _osx_support        flake8              pprint              types
# _pyio               flask               profile             unicodecsv
# _pytest             flask_cors          prompt_toolkit      unicodedata
# _random             fnmatch             pstats              unittest
# _scandir            formatter           psutil              urllib
# _sha                fpformat            pty                 urllib2
# _sha256             fractions           py                  urlparse
# _sha512             ftplib              py_compile          user
# _socket             funcsigs            pyclbr              uu
# _sqlite3            functools           pycodestyle         uuid
# _sre                functools32         pycosat             warnings
# _ssl                future_builtins     pycparser           wave
# _strptime           gc                  pycurl              wcwidth
# _struct             genericpath         pydoc               weakref
# _subprocess         getopt              pydoc_data          webbrowser
# _symtable           getpass             pydocstyle          werkzeug
# _system_path        gettext             pyexpat             wheel
# _testcapi           gevent              pyflakes            whichdb
# _threading_local    glob                pygments            widgetsnbextension
# _tkinter            greenlet            pylab               win2kras
# _vendor             grin                pylama              win32api
# _warnings           gzip                pylama_pylint       win32clipboard
# _weakref            h5py                pylint              win32com
# _weakrefset         hashlib             pyodbc              win32con
# _win32sysloader     heapdict            pyparsing           win32console
# _winreg             heapq               pytest              win32cred
# _winxptheme         hmac                pythoncom           win32crypt
# abc                 hotshot             pytz                win32cryptcon
# adodbapi            html5lib            pywin               win32event
# afxres              htmlentitydefs      pywin32_testutil    win32evtlog
# aifc                htmllib             pywintypes          win32evtlogutil
# alabaster           httplib             pywt                win32file
# anaconda_navigator  idlelib             pyximport           win32gui
# anaconda_project    idna                qtawesome           win32gui_struct
# antigravity         ihooks              qtconsole           win32help
# anydbm              imageop             qtpy                win32inet
# argparse            imagesize           quopri              win32inetcon
# array               imaplib             random              win32job
# asn1crypto          imghdr              rasutil             win32lz
# ast                 imp                 re                  win32net
# astroid             importlib           regcheck            win32netcon
# astropy             imputil             regutil             win32pdh
# asynchat            inspect             repr                win32pdhquery
# asyncore            io                  requests            win32pdhutil
# atexit              ipaddress           rexec               win32pipe
# audiodev            ipykernel           rfc822              win32print
# audioop             ipykernel_launcher  rlcompleter         win32process
# autoreload          ipython_genutils    rmagic              win32profile
# babel               ipywidgets          robotparser         win32ras
# backports           isapi               rope                win32rcparser
# backports_abc       isort               ruamel_yaml         win32security
# base64              itertools           run                 win32service
# bdb                 itsdangerous        runpy               win32serviceutil
# binascii            jdcal               scandir             win32timezone
# binhex              jedi                sched               win32trace
# binstar_client      jinja2              scipy               win32traceutil
# bisect              json                scripts             win32transaction
# bitarray            jsonschema          seaborn             win32ts
# blaze               jupyter             select              win32ui
# bleach              jupyter_client      servicemanager      win32uiole
# bokeh               jupyter_console     sets                win32verstamp
# boto                jupyter_core        setuptools          win32wnet
# bottleneck          keyword             sgmllib             win_unicode_console
# brain_builtin_inference lazy_object_proxy   sha                 winerror
# brain_dateutil      lib2to3             shelve              winioctlcon
# brain_gi            linecache           shlex               winnt
# brain_mechanize     llvmlite            shutil              winperf
# brain_nose          locale              signal              winsound
# brain_numpy         locket              simplegeneric       winxpgui
# brain_pytest        logging             singledispatch      winxptheme
# brain_qt            lxml                singledispatch_helpers wrapt
# brain_six           macpath             sip                 wsgiref
# brain_ssl           macurl2path         sipconfig           xdrlib
# brain_stdlib        mailbox             sipdistutils        xlrd
# bs4                 mailcap             site                xlsxwriter
# bsddb               markupbase          six                 xlwings
# bz2                 markupsafe          skimage             xlwt
# cPickle             marshal             sklearn             xml
# cProfile            math                smtpd               xmllib
# cStringIO           matplotlib          smtplib             xmlrpclib
# calendar            mccabe              sndhdr              xxsubtype
# cdecimal            md5                 snowballstemmer     yaml
# cffi                menuinst            socket              zict
# cgi                 mhlib               sortedcollections   zipfile
# cgitb               mimetools           sortedcontainers    zipimport
# chardet             mimetypes           sphinx              zlib
# chunk               mimify              sphinxify           zmq
# click               mistune             spyder
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose descriptions contain the word "spam".

# %%
tt is None
# Out:
# True

# %%
modules = [m for m in mod.modules]
print modules
for m in modules:
    print m
    try:
        globals()[m] = importlib.import_module(m)
    except Exception as e:
        try:
            parts = m.split('.')
            parts.pop()
            m2 = '.'.join(parts)
            globals()[m2] = importlib.import_module(m2)
        except Exception as e:
            print e
# Out:
# ['email.MIMEAudio', 'IPython.core.error', 'ipython_genutils.py3compat', 'traitlets.config.sys', 'concurrent.futures.types', 'ipykernel.parentpoller', 'traitlets.config.decorator', 'ctypes.os', 'IPython.terminal.pt_inputhooks.importlib', 'runpy', 'gc', 'ipykernel.os', 'prompt_toolkit.terminal.vt100_output', 'email.iterators', 'prompt_toolkit.key_binding.six', 'win32com.os', 'pygments.filters', 'IPython.utils.pprint', 'email.warnings', 'jupyter_client.blocking.channels', 'ipykernel.kernelbase', 'IPython.core.msvcrt', 'logging.weakref', 'traitlets.traitlets', 'dateutil.tz.os', 'pprint', 'pkg_resources.extern.packaging.specifiers', 'prompt_toolkit.key_binding.manager', 'IPython.utils.simplegeneric', 'prompt_toolkit.key_binding.bindings.vi', 'ipykernel.traitlets', 'IPython.core.magics.display', 'colorama.ansi', 'timeit', 'IPython.terminal.sys', 'string', 'prompt_toolkit.__future__', 'prompt_toolkit.layout.six', 'multiprocessing.threading', 'jupyter_client.blocking.__future__', 'IPython.utils.timing', 'encodings.utf_8', 'email.codecs', 'email.quoprimime', 'IPython.terminal.embed', 'datetime', 'ipykernel.errno', 'zmq.backend.cython.utils', 'traitlets.six', 'ipython_genutils', 'prompt_toolkit.eventloop.abc', 'array', 'cmd', 'IPython.core.debugger', 'concurrent.futures.collections', 'IPython.core.displayhook', 'zmq.eventloop.Queue', 'IPython.lib.IPython', 'pygments.lexers.pygments', 'prompt_toolkit.styles.prompt_toolkit', 'shlex', 'zmq.backend.cython.zmq', 'IPython.core.ultratb', 'prompt_toolkit.clipboard', 'dis', 'prompt_toolkit.filters.utils', 'zlib', 'logging.threading', 'IPython.core.splitinput', 'IPython.lib.types', 'pkg_resources._vendor.pprint', 'ipywidgets.widgets.domwidget', 'pygments.styles.pygments', 'IPython.terminal.ipapp', 'IPython.terminal.unicodedata', 'IPython.core.excolors', 'ipykernel.datapub', 'IPython.utils.tempfile', 'prompt_toolkit.layout.screen', 'IPython.core.inspect', 'IPython.lib.getpass', 'abc', 'IPython.core.displaypub', 'zmq.utils.sys', 'bdb', 'ipykernel._subprocess', 'ast', 'ipython_genutils.sys', 'ipykernel.copy_reg', 'IPython.core.mimetypes', 'traitlets.os', 'jupyter_client.blocking.client', 'IPython.utils.io', 'ntpath', 'UserDict', 'zmq.sugar.warnings', 'jupyter_client.adapter', 'pygments.pkg_resources', 'IPython.utils.openpy', 'IPython.core.alias', 'inspect', 'ipykernel.warnings', 'IPython.core.datetime', 'dateutil.tz.tz', 'prompt_toolkit.terminal', 'ipython_genutils.re', '_ctypes', 'glob', 'exceptions', 'json.scanner', 'concurrent.futures.itertools', 'colorama.winterm', 'jupyter_client.hmac', 'codecs', 'dateutil.warnings', 'jupyter_client.blocking.functools', 'prompt_toolkit.clipboard.six', 'IPython.core.shadowns', 'traitlets.config.loader', 'ipykernel.__future__', 'IPython.core.magics.extension', 'ipython_genutils.locale', 'traitlets.config.json', 'IPython.utils.shutil', 'StringIO', 'concurrent.futures.atexit', 'wcwidth', 'colorama.win32', 'weakref', 'prompt_toolkit.styles.__future__', 'traitlets', 'ipywidgets.os', 'ipykernel.math', 'dateutil.tz.ctypes', 'IPython.core.display', 'IPython.core.usage', 'ipykernel.heartbeat', 'IPython.terminal', 'base64', 'jupyter_client.os', '_sre', 'pygments.formatters.html', 'email.FeedParser', 'ipykernel.iostream', 'IPython.core.json', 'traitlets.types', 'sqlite3.dbapi2', 'IPython', 'copy_reg', 'pkg_resources._vendor.datetime', 'prompt_toolkit.clipboard.prompt_toolkit', 'IPython.core.errno', 'IPython.core.subprocess', 'ctypes._ctypes', '_heapq', 'IPython.core.display_trap', 'zmq.sugar.constants', 'prompt_toolkit.key_binding.bindings.prompt_toolkit', 'zmq.backend.cython.time', 'binascii', 'IPython.lib.contextlib', 'pygments.lexers.python', 'email.MIMEMessage', 'IPython.core.logger', 'email.sys', 'jupyter_client.manager', 'tokenize', 'pygments.formatters.sys', 'IPython.core.StringIO', 'pkg_resources._vendor.six.moves.urllib', 'email.MIMEText', 'IPython.core.magics.io', 'traitlets.utils.inspect', 'pkg_resources.extern.six.moves.urllib', 'cPickle', 'jupyter_client.sessi ...
# email.MIMEAudio
# IPython.core.error
# ipython_genutils.py3compat
# traitlets.config.sys
# concurrent.futures.types
# ipykernel.parentpoller
# traitlets.config.decorator
# ctypes.os
# IPython.terminal.pt_inputhooks.importlib
# runpy
# gc
# ipykernel.os
# prompt_toolkit.terminal.vt100_output
# email.iterators
# prompt_toolkit.key_binding.six
# win32com.os
# pygments.filters
# IPython.utils.pprint
# email.warnings
# jupyter_client.blocking.channels
# ipykernel.kernelbase
# IPython.core.msvcrt
# logging.weakref
# traitlets.traitlets
# dateutil.tz.os
# pprint
# pkg_resources.extern.packaging.specifiers
# prompt_toolkit.key_binding.manager
# IPython.utils.simplegeneric
# prompt_toolkit.key_binding.bindings.vi
# ipykernel.traitlets
# IPython.core.magics.display
# colorama.ansi
# timeit
# IPython.terminal.sys
# string
# prompt_toolkit.__future__
# prompt_toolkit.layout.six
# multiprocessing.threading
# jupyter_client.blocking.__future__
# IPython.utils.timing
# encodings.utf_8
# email.codecs
# email.quoprimime
# IPython.terminal.embed
# datetime
# ipykernel.errno
# zmq.backend.cython.utils
# traitlets.six
# ipython_genutils
# prompt_toolkit.eventloop.abc
# array
# cmd
# IPython.core.debugger
# concurrent.futures.collections
# IPython.core.displayhook
# zmq.eventloop.Queue
# IPython.lib.IPython
# pygments.lexers.pygments
# prompt_toolkit.styles.prompt_toolkit
# shlex
# zmq.backend.cython.zmq
# IPython.core.ultratb
# prompt_toolkit.clipboard
# dis
# prompt_toolkit.filters.utils
# zlib
# logging.threading
# IPython.core.splitinput
# IPython.lib.types
# pkg_resources._vendor.pprint
# ipywidgets.widgets.domwidget
# pygments.styles.pygments
# IPython.terminal.ipapp
# IPython.terminal.unicodedata
# IPython.core.excolors
# ipykernel.datapub
# IPython.utils.tempfile
# prompt_toolkit.layout.screen
# IPython.core.inspect
# IPython.lib.getpass
# abc
# IPython.core.displaypub
# zmq.utils.sys
# bdb
# ipykernel._subprocess
# ast
# ipython_genutils.sys
# ipykernel.copy_reg
# IPython.core.mimetypes
# traitlets.os
# jupyter_client.blocking.client
# IPython.utils.io
# ntpath
# UserDict
# zmq.sugar.warnings
# jupyter_client.adapter
# pygments.pkg_resources
# IPython.utils.openpy
# IPython.core.alias
# inspect
# ipykernel.warnings
# IPython.core.datetime
# dateutil.tz.tz
# prompt_toolkit.terminal
# ipython_genutils.re
# _ctypes
# glob
# exceptions
# json.scanner
# concurrent.futures.itertools
# colorama.winterm
# jupyter_client.hmac
# codecs
# dateutil.warnings
# jupyter_client.blocking.functools
# prompt_toolkit.clipboard.six
# IPython.core.shadowns
# traitlets.config.loader
# ipykernel.__future__
# IPython.core.magics.extension
# ipython_genutils.locale
# traitlets.config.json
# IPython.utils.shutil
# StringIO
# concurrent.futures.atexit
# wcwidth
# colorama.win32
# weakref
# prompt_toolkit.styles.__future__
# traitlets
# ipywidgets.os
# ipykernel.math
# dateutil.tz.ctypes
# IPython.core.display
# IPython.core.usage
# ipykernel.heartbeat
# IPython.terminal
# base64
# jupyter_client.os
# _sre
# pygments.formatters.html
# email.FeedParser
# ipykernel.iostream
# IPython.core.json
# traitlets.types
# sqlite3.dbapi2
# IPython
# copy_reg
# pkg_resources._vendor.datetime
# prompt_toolkit.clipboard.prompt_toolkit
# IPython.core.errno
# IPython.core.subprocess
# ctypes._ctypes
# _heapq
# IPython.core.display_trap
# zmq.sugar.constants
# prompt_toolkit.key_binding.bindings.prompt_toolkit
# zmq.backend.cython.time
# binascii
# IPython.lib.contextlib
# pygments.lexers.python
# email.MIMEMessage
# IPython.core.logger
# email.sys
# jupyter_client.manager
# tokenize
# pygments.formatters.sys
# IPython.core.StringIO
# pkg_resources._vendor.six.moves.urllib
# email.MIMEText
# IPython.core.magics.io
# traitlets.utils.inspect
# pkg_resources.extern.six.moves.urllib
# cPickle
# jupyter_client.session
# ipykernel.comm.ipykernel
# prompt_toolkit.pygments
# IPython.core.magics.errno
# jupyter_client.blocking.jupyter_client
# IPython.utils.encoding
# IPython.core.ast
# IPython.core.keyword
# IPython.lib.os
# prompt_toolkit.clipboard.base
# prompt_toolkit.styles.abc
# prompt_toolkit.terminal.__future__
# zmq.backend.cython.cPickle
# IPython.core.getipython
# ipykernel.cPickle
# prompt_toolkit.key_binding.input_processor
# unicodedata
# zmq
# IPython.core.page
# _ast
# IPython.utils.process
# jupyter_client.sys
# IPython.utils.ctypes
# jupyter_client.io
# zmq.sugar.tracker
# jupyter_client.blocking.getpass
# pkg_resources._vendor.copy
# zmq.backend.cython.codecs
# encodings.aliases
# fnmatch
# sre_parse
# tornado.concurrent
# jupyter_core.version
# ipywidgets.widgets.ipykernel
# numbers
# pygments.regexopt
# zmq.sugar.version
# jupyter_client.launcher
# logging.cStringIO
# encodings.cp1252
# IPython.terminal.debugger
# pkg_resources._vendor.os
# pkg_resources.extern.six
# prompt_toolkit.styles.six
# _scandir
# IPython.utils.shlex
# IPython.core.magics.signal
# ipykernel.comm.ipython_genutils
# prompt_toolkit.key_binding.abc
# traitlets.inspect
# email.message
# prompt_toolkit.eventloop.base
# ipykernel.zmq
# IPython.utils.platform
# strop
# pygments.util
# jupyter_client.jupyter_client
# IPython.core.history
# concurrent.futures.process
# six
# IPython.shutil
# jupyter_client.connect
# ipython_genutils.textwrap
# prompt_toolkit.abc
# IPython.utils.ipstruct
# traitlets._version
# dateutil.math
# IPython.extensions.__future__
# jupyter_client.jupyter_core
# concurrent.pkgutil
# ctypes.util
# dateutil.relativedelta
# htmlentitydefs
# zmq.backend.cython.threading
# ipywidgets.widgets.widget_link
# jupyter_core.tempfile
# ipywidgets.widgets.contextlib
# jupyter_client.blocking
# jupyter_client.multikernelmanager
# codeop
# email.parser
# pygments.formatter
# os.path
# IPython.core.magics.time
# argparse
# prompt_toolkit.eventloop.callbacks
# email.base64mime
# simplegeneric
# IPython.core.payload
# marshal
# _weakrefset
# zmq.backend.select
# email.string
# colorama.atexit
# ipywidgets.widgets.widget
# traitlets.config.configurable
# _cython_0_25_1
# IPython.core.traitlets
# pygments.styles
# ipykernel.threading
# win32com.shell.win32com
# prompt_toolkit.io
# pygments.pygments
# functools
# pythoncom.__univgw
# prompt_toolkit.subprocess
# sysconfig
# json.encoder
# email.MIMEImage
# concurrent.futures.concurrent
# prompt_toolkit.terminal.win32_input
# jupyter_client._version
# sqlite3.collections
# pygments.formatters.types
# zmq.backend.cython.error
# dateutil.tz.time
# prompt_toolkit.eventloop.__future__
# uuid
# jupyter_core.os
# tempfile
# prompt_toolkit.terminal.conemu_output
# win32com.shell
# prompt_toolkit.tempfile
# imp
# pkg_resources._vendor
# prompt_toolkit.wcwidth
# multiprocessing.os
# jupyter_core.sys
# IPython.utils.tempdir
# ipywidgets.widgets.__future__
# multiprocessing.itertools
# backports.shutil_get_terminal_size.collections
# enum.sys
# zmq.libzmq
# jupyter_client.random
# traitlets.utils.sentinel
# IPython.core.magics.logging
# prompt_toolkit.ctypes
# zmq.zmq
# email.calendar
# prompt_toolkit.input
# pkg_resources._vendor.six
# zmq.eventloop.tornado
# email.email
# IPython.core.traceback
# IPython.utils._tokenize_py2
# IPython.core.__main__
# ipython_genutils._version
# prompt_toolkit.layout.mouse_handlers
# prompt_toolkit.types
# email.urllib
# concurrent.futures.logging
# win32com.gen_py
# decorator
# IPython.core.zipimport
# pygments.lexers.sys
# pygments.unistring
# IPython.terminal.interactiveshell
# IPython.extensions.traitlets
# zmq.backend.cython.context
# ipywidgets.widgets.itertools
# ipykernel.ipykernel
# IPython.core.warnings
# IPython.utils.imp
# logging.handlers
# dateutil.tz.datetime
# token
# prompt_toolkit.key_binding.digraphs
# prompt_toolkit.auto_suggest
# prompt_toolkit.buffer
# dateutil.operator
# IPython.testing.sys
# pygments.formatters.os
# IPython.utils.warnings
# IPython.core.magics.gc
# dateutil.tz.struct
# cStringIO
# IPython.utils.errno
# backports.shutil_get_terminal_size.struct
# IPython.core.io
# IPython.terminal.pt_inputhooks
# IPython.core.magics.namespace
# traitlets.config.copy
# ipywidgets.widgets.widget_color
# traitlets.utils.ipython_genutils
# zmq.sugar.frame
# multiprocessing.process
# pkg_resources.extern.packaging.requirements
# prompt_toolkit.terminal.win32_output
# encodings
# IPython.core.magics.history
# IPython.core.__future__
# zmq.utils.strtypes
# prompt_toolkit.layout.toolbars
# ipykernel.comm.uuid
# prompt_toolkit.styles.pygments
# IPython.core.interactiveshell
# ipywidgets.widgets.widget_core
# traitlets.ipython_genutils
# IPython.core.operator
# IPython.core.crashhandler
# IPython.utils
# _subprocess
# prompt_toolkit.layout.time
# prompt_toolkit.threading
# pkg_resources._vendor.packaging.__about__
# re
# pygments.filters.re
# jupyter_client.warnings
# email.quopri
# IPython.utils.capture
# pkg_resources._vendor.__builtin__
# ipykernel.ipkernel
# sqlite3.time
# dateutil._common
# math
# IPython.core.IPython
# pygments.formatters.fnmatch
# wcwidth.__future__
# ipykernel.comm.manager
# IPython.core.importlib
# ipython_genutils.errno
# dateutil.tz.six
# IPython.lib.sys
# prompt_toolkit.interface
# email.re
# zmq.utils.constant_names
# prompt_toolkit.key_binding.bindings.six
# ctypes.struct
# IPython.utils.colorable
# ipykernel.ctypes
# ipywidgets.widgets.IPython
# prompt_toolkit.filters
# _locale
# IPython.core.logging
# logging
# prompt_toolkit.enums
# thread
# ipywidgets.widgets.interaction
# prompt_toolkit.eventloop
# traceback
# ipykernel.signal
# multiprocessing
# concurrent.futures.time
# IPython.core.copy
# IPython.core.builtin_trap
# zmq.backend.platform
# IPython.utils.coloransi
# multiprocessing.util
# colorama.os
# pkg_resources._vendor.packaging.markers
# pkg_resources._vendor.packaging.version
# ipywidgets.widgets.widget_layout
# prompt_toolkit.filters.six
# _collections
# prompt_toolkit.mouse_events
# ipykernel.jupyter_core
# dateutil.re
# prompt_toolkit.key_binding.bindings.__future__
# traitlets.config.ast
# multiprocessing.sys
# ipykernel.uuid
# ipywidgets.widgets.widget_button
# ipywidgets.IPython
# pygments.filter
# email.Errors
# IPython.utils.locale
# ctypes.sys
# IPython.core.magics.config
# pygments.lexers.__future__
# posixpath
# jupyter_client.channels
# pkg_resources._vendor.packaging._compat
# email.cStringIO
# IPython.utils._sysinfo
# prompt_toolkit.filters.cli
# traitlets.logging
# colorama.contextlib
# types
# zmq.backend.cython._device
# prompt_toolkit.utils
# prompt_toolkit.clipboard.in_memory
# IPython.core.linecache
# ipywidgets.widgets.widget_string
# _win32sysloader
# json._json
# ipykernel.jupyter_client
# _codecs
# traitlets.contextlib
# ipykernel.comm.sys
# IPython.core.unicodedata
# enum.collections
# json.sys
# win32com.win32api
# IPython.utils.os
# IPython.extensions.inspect
# concurrent.futures.multiprocessing
# pygments.time
# zmq.eventloop.ioloop
# copy
# ipykernel.datetime
# prompt_toolkit.styles.collections
# ipykernel.comm.logging
# ipython_genutils.shutil
# hashlib
# prompt_toolkit
# email.errors
# keyword
# ipython_genutils.random
# pkg_resources._vendor.packaging
# IPython.extensions.IPython
# ipywidgets.widgets.sys
# IPython.core.hashlib
# ipywidgets.widgets.widget_output
# pygments.lexers.fnmatch
# prompt_toolkit.terminal.ctypes
# IPython.utils.generics
# ipykernel.connect
# backports.shutil_get_terminal_size.os
# prompt_toolkit.layout.collections
# sre_compile
# ipykernel
# _hashlib
# prompt_toolkit.layout.utils
# IPython.utils.ulinecache
# zmq.eventloop.cPickle
# IPython.core.magics.code
# IPython.core.sqlite3
# IPython.core.bdb
# logging.collections
# IPython.core.threading
# email.base64
# pygments.__future__
# __main__
# colorama.initialise
# multiprocessing.atexit
# ipykernel.itertools
# zmq.backend.cython.message
# prompt_toolkit.string
# prompt_toolkit.layout.re
# IPython.extensions.textwrap
# prompt_toolkit.layout.__future__
# ipykernel.binascii
# dateutil.parser
# prompt_toolkit.token
# IPython.utils.terminal
# jupyter_client.ipython_genutils
# encodings.codecs
# ipywidgets.widgets.widget_selection
# ipywidgets
# IPython.utils.__builtin__
# IPython.terminal.os
# IPython.lib.threading
# zmq.utils.jsonapi
# email.MIMEMultipart
# pkg_resources._vendor.win32com
# ipywidgets.widgets.datetime
# IPython.core.completer
# ipykernel.base64
# _ssl
# ipykernel.types
# IPython.utils.sys
# IPython.utils.re
# tornado
# IPython.lib.clipboard
# encodings.ascii
# ipykernel.getpass
# IPython.utils.inspect
# zmq.backend.cython.sys
# IPython.core.base64
# pkg_resources.extern.appdirs
# colorama
# _sqlite3
# ipython_genutils.text
# IPython.core.shellapp
# email.feedparser
# email.MIMEBase
# prompt_toolkit.selection
# plistlib
# multiprocessing._multiprocessing
# concurrent.futures.sys
# pygments.modeline
# pkg_resources._vendor.collections
# IPython.utils.wildcard
# IPython.core.extensions
# IPython.utils.tokenutil
# _io
# linecache
# _strptime
# ipywidgets.widgets.trait_types
# IPython.core.compilerop
# ipykernel.comm
# jupyter_client.zmq
# hmac
# tornado.platform.interface
# scandir
# prompt_toolkit.terminal.six
# dateutil.collections
# prompt_toolkit.key_binding.bindings.named_commands
# _multiprocessing
# ipywidgets.widgets.traitlets
# IPython.core.magics.osm
# jupyter_client.json
# random
# _bisect
# zmq.sugar.context
# subprocess
# IPython.extensions.storemagic
# prompt_toolkit.key_binding.weakref
# prompt_toolkit.key_binding.vi_state
# pygments.operator
# logging.os
# ctypes._endian
# encodings.encodings
# ipykernel.numbers
# colorama.ansitowin32
# pygments.formatters._mapping
# logging.stat
# email.time
# importlib
# prompt_toolkit.styles.from_pygments
# IPython.core.magic
# ipywidgets.widgets.ipython_genutils
# IPython.utils.dir2
# _json
# prompt_toolkit.key_binding.bindings.basic
# pkg_resources._vendor.warnings
# ipykernel.logging
# traitlets.config.argparse
# ipython_genutils.importstring
# jupyter_client.blocking.traitlets
# logging.thread
# cProfile
# prompt_toolkit.styles.defaults
# prompt_toolkit.buffer_mapping
# prompt_toolkit.history
# IPython.lib.re
# pathlib2
# pygments.sys
# prompt_toolkit.styles
# concurrent.futures.threading
# zipfile
# repr
# ipykernel.traceback
# ssl
# traitlets.config.__future__
# prompt_toolkit.reactive
# ipywidgets.widgets.widget_image
# ipython_genutils.platform
# prompt_toolkit.terminal.msvcrt
# ipywidgets.widgets.numbers
# _lsprof
# IPython.os
# pygments.lexer
# prompt_toolkit.completion
# zmq.error
# pkg_resources._vendor.weakref
# dateutil.tz.operator
# traitlets.config.collections
# IPython.utils.hashlib
# IPython.terminal.traitlets
# bisect
# traitlets.config
# IPython.utils.IPython
# email
# pydoc
# threading
# prompt_toolkit.keys
# IPython.core.prefilter
# ipywidgets.widgets.widget_float
# prompt_toolkit.styles.from_dict
# pkg_resources._vendor.six.moves
# pkg_resources._vendor.pyparsing
# IPython.lib.datetime
# ctypes.wintypes
# jupyter_core.paths
# IPython.core.events
# email.Message
# jupyter_client.blocking.sys
# IPython.core.textwrap
# locale
# ipywidgets.widgets.widget_date
# prompt_toolkit.document
# atexit
# email.quopriMIME
# IPython.core.autocall
# IPython.core.sys
# ipykernel.serialize
# calendar
# ipykernel.comm.traitlets
# IPython.utils.backports
# IPython.core.magics.__future__
# traitlets.sys
# dateutil
# traitlets.utils.bunch
# backports.shutil_get_terminal_size.get_terminal_size
# tornado.log
# jupyter_client.managerabc
# urllib
# IPython.core.os
# IPython.lib.io
# pkg_resources.extern.packaging.version
# pygments.StringIO
# ipykernel.displayhook
# pkg_resources._vendor.string
# zmq.sys
# ctypes.subprocess
# prompt_toolkit.validation
# zmq.backend.cython.struct
# ipywidgets.widgets.collections
# IPython.utils.path
# ipywidgets.widgets.inspect
# IPython.core.atexit
# pygments.plugin
# prompt_toolkit.layout.controls
# zmq.utils
# jupyter_client.localinterfaces
# Queue
# jupyter_client.shutil
# ctypes
# IPython.lib.collections
# IPython.core.magics.re
# IPython.utils._process_common
# pickleshare
# win32com.win32com
# ipython_genutils.functools
# traitlets.config.application
# jupyter_client.socket
# tornado.stack_context
# ipykernel.atexit
# prompt_toolkit.key_binding.bindings
# prompt_toolkit.filters.base
# itertools
# dateutil.tz.win
# opcode
# colorama.sys
# pstats
# prompt_toolkit.key_binding.bindings.math
# ipykernel.IPython
# traitlets.config.six
# pdb
# IPython.terminal.shortcuts
# IPython.core.magics.subprocess
# IPython.terminal.signal
# IPython.extensions.os
# IPython.core.magics.atexit
# six.moves
# IPython.terminal.logging
# zmq.errno
# prompt_toolkit.key_binding.collections
# IPython.testing
# prompt_toolkit.renderer
# sqlite3.datetime
# zmq.sugar.socket
# prompt_toolkit.key_binding.bindings.string
# pygments.lexers.re
# prompt_toolkit.shortcuts
# pygments
# logging.errno
# win32com.pythoncom
# dateutil.tz.copy
# prompt_toolkit.signal
# email.uu
# prompt_toolkit.shlex
# IPython.core.hooks
# email.socket
# IPython.display
# pkgutil
# IPython.core.tokenize
# platform
# zmq.backend
# IPython.lib.__future__
# IPython.utils.sentinel
# ipykernel.tornado
# IPython.core.magics.warnings
# logging.struct
# sre_constants
# zmq.backend.os
# json
# pygments.styles.default
# prompt_toolkit.filters.prompt_toolkit
# jupyter_client.pprint
# jupyter_client.jsonutil
# pkg_resources._vendor.sre_constants
# zmq.sugar.random
# ipykernel.platform
# IPython.lib.warnings
# json.re
# prompt_toolkit.sys
# zmq.utils.itertools
# prompt_toolkit.layout.lexers
# zmq.eventloop
# ipywidgets.widgets
# pkg_resources._vendor.sys
# email.utils
# IPython.IPython
# prompt_toolkit.application
# zmq.sugar
# nturl2path
# logging.cPickle
# IPython.core.completerlib
# logging.socket
# email.MIMENonMultipart
# getpass
# ipykernel.sys
# dateutil.io
# dateutil.tz.contextlib
# prompt_toolkit.inspect
# prompt_toolkit.functools
# storemagic
# wcwidth.table_zero
# prompt_toolkit.textwrap
# email.random
# ipython_genutils.__builtin__
# concurrent.futures.Queue
# multiprocessing.weakref
# jupyter_client.datetime
# IPython.terminal.prompt_toolkit
# jupyter_client.binascii
# ipykernel.thread
# json.decoder
# traitlets.enum
# logging.atexit
# IPython.core.magics.os
# ipykernel.kernelapp
# pkg_resources._vendor.packaging.specifiers
# tornado.platform.auto
# pkg_resources._vendor.appdirs
# IPython.utils.linecache
# site
# pkg_resources
# ipywidgets.widgets.widget_selectioncontainer
# IPython.core.shutil
# dateutil.tz
# io
# ipython_genutils.string
# prompt_toolkit.search_state
# pkg_resources._vendor.packaging._structures
# IPython.core.pygments
# shutil
# IPython.utils.random
# jupyter_client.clientabc
# prompt_toolkit.clipboard.collections
# pygments.filters.pygments
# zmq.sugar.zmq
# zmq.backend.sys
# prompt_toolkit.terminal.os
# prompt_toolkit.styles.base
# IPython.lib.logging
# ipykernel.zmqshell
# IPython.utils.decorators
# IPython.testing.skipdoctest
# email.binascii
# IPython.core.magics.script
# sqlite3
# pygments.formatters.pygments
# prompt_toolkit.weakref
# IPython.core.magics.basic
# pkg_resources.extern
# traitlets.config.traitlets
# IPython.core.macro
# ipywidgets.widgets.widget_style
# IPython.core.magics.pprint
# IPython.utils.data
# dateutil.time
# json.json
# IPython.core.types
# sys
# IPython.terminal.IPython
# multiprocessing.subprocess
# IPython.core.string
# ipykernel.re
# email.Header
# jupyter_client.traitlets
# tornado.util
# prompt_toolkit.terminal.sys
# prompt_toolkit.bisect
# dateutil.string
# prompt_toolkit.output
# _weakref
# pygments.formatters.__future__
# IPython.core.inputtransformer
# pkg_resources.extern.pyparsing
# urlparse
# jupyter_client.dateutil
# prompt_toolkit.key_binding.prompt_toolkit
# pygments.cStringIO
# ipywidgets.widgets.re
# IPython.core.decorator
# IPython.core.application
# ipykernel._version
# IPython.core
# prompt_toolkit.layout.processors
# IPython.core.pprint
# traitlets.utils.six
# logging.logging
# prompt_toolkit.key_binding.registry
# heapq
# concurrent.futures._base
# concurrent.futures
# IPython.core.time
# prompt_toolkit.terminal.array
# prompt_toolkit.key_binding.bindings.completion
# IPython.extensions
# ipykernel.pickleutil
# prompt_toolkit.key_binding.defaults
# zmq.backend.cython.socket
# select
# IPython.terminal.pt_inputhooks.os
# IPython.core.oinspect
# pkg_resources.extern.packaging
# zmq.sugar.time
# prompt_toolkit.key_binding.bindings.codecs
# zmq.sugar.attrsettr
# email.mime
# msvcrt
# zmq.backend.cython.constants
# ipython_genutils.path
# IPython.utils._signatures
# jupyter_client.logging
# struct
# IPython.utils.strdispatch
# IPython.core.inputsplitter
# IPython.utils.tokenize2
# prompt_toolkit.terminal.errno
# IPython.lib
# sqlite3._sqlite3
# prompt_toolkit.key_binding
# IPython.utils.string
# collections
# jupyter_client.cPickle
# prompt_toolkit.eventloop.six
# prompt_toolkit.filters.collections
# zmq.sugar.atexit
# email.Parser
# ipykernel.comm.comm
# IPython.extensions.sys
# backports.shutil_get_terminal_size.ctypes
# traitlets.utils
# ipython_genutils.encoding
# dateutil.tz._common
# zipimport
# IPython.core.struct
# zmq.ctypes
# IPython.core.magics.execution
# pkg_resources.extern.sys
# pkg_resources.extern.packaging.markers
# jupyter_client
# IPython.terminal.magics
# textwrap
# zmq.platform
# IPython.lib.subprocess
# pkg_resources._vendor.threading
# IPython.core.codeop
# jupyter_client.channelsabc
# prompt_toolkit.filters.__future__
# jupyter_client.blocking.zmq
# traitlets.config.re
# zmq.backend.cython._version
# multiprocessing.multiprocessing
# IPython.lib.random
# ipykernel.codeutil
# IPython.utils.frame
# signal
# IPython.core.payloadpage
# prompt_toolkit.terminal.prompt_toolkit
# prompt_toolkit.filters.abc
# prompt_toolkit.re
# IPython.terminal.warnings
# prompt_toolkit.win32_types
# prompt_toolkit.layout.containers
# quopri
# IPython.core.magics
# pygments.lexers.types
# zmq.eventloop.zmqstream
# IPython.core.getopt
# jupyter_client.kernelspec
# IPython.lib.display
# ipywidgets._version
# email.charset
# IPython.terminal.prompts
# mimetypes
# IPython.core.magics.auto
# traitlets.log
# dateutil.tz.sys
# ipykernel.io
# _winreg
# prompt_toolkit.key_binding.bindings.emacs
# pygments.lexers._mapping
# IPython.utils.token
# email.Generator
# IPython.utils.module_paths
# pygments.lexers.os
# logging.re
# logging.traceback
# IPython.core.magic_arguments
# pygments.codecs
# traitlets.utils.getargspec
# pkg_resources._vendor.traceback
# wcwidth.table_wide
# warnings
# IPython.utils.sysinfo
# backports
# ipywidgets.widgets.valuewidget
# IPython.core.argparse
# IPython.lib.security
# email.encoders
# win32com.imp
# IPython.core.magics.traitlets
# pkg_resources._vendor.re
# pygments.formatters.re
# tornado.escape
# traitlets.config.logging
# ipython_genutils.warnings
# IPython.utils.subprocess
# zmq.eventloop.__future__
# jupyter_client.abc
# prompt_toolkit.key_binding.bindings.itertools
# IPython.utils.syspathcontext
# IPython.terminal.__future__
# traitlets.config.ipython_genutils
# enum
# pygments.os
# prompt_toolkit.prompt_toolkit
# IPython.utils.PyColorize
# ipywidgets.widgets.widget_int
# tornado.platform.common
# prompt_toolkit.time
# IPython.terminal.wcwidth
# logging.sys
# dateutil.calendar
# IPython.utils._process_win32
# _functools
# colorama.ctypes
# email.Iterators
# socket
# ipykernel.socket
# IPython.core.pylabtools
# email.base64MIME
# backports.shutil_get_terminal_size
# ipywidgets.widgets.widget_bool
# prompt_toolkit.datetime
# IPython.utils.contexts
# dateutil.__future__
# IPython.core.imp
# email.Charset
# zmq.eventloop.sys
# ipywidgets.widgets.base64
# IPython.core.pdb
# ipywidgets.widgets.widget_box
# os
# IPython.terminal.ptutils
# zmq.sugar.sys
# win32api
# dateutil.six
# ipykernel.copy
# __future__
# tornado.speedups
# traitlets.utils.functools
# IPython.lib.deepreload
# zmq.sugar.cPickle
# prompt_toolkit.clipboard.__future__
# __builtin__
# zmq.backend.cython
# jupyter_client.blocking.Queue
# prompt_toolkit.cache
# prompt_toolkit.layout.itertools
# operator
# prompt_toolkit.layout.menus
# json.struct
# pygments.token
# zmq.backend.cython.random
# zmq.backend.cython._poll
# IPython.core.re
# errno
# pkg_resources._vendor.packaging.requirements
# _socket
# traitlets.config.os
# email.Utils
# prompt_toolkit.clipboard.abc
# ipywidgets.widgets.warnings
# IPython.core.glob
# IPython.core.abc
# prompt_toolkit.layout.prompt_toolkit
# jupyter_client.re
# pygments.itertools
# IPython.lib.backgroundjobs
# zmq.eventloop.zmq
# _warnings
# IPython.core.magics.sys
# IPython.core.latex_symbols
# prompt_toolkit.key_binding.__future__
# IPython.utils.text
# encodings.__builtin__
# IPython.utils.__future__
# ipython_genutils.os
# prompt_toolkit.layout.math
# email._parseaddr
# IPython.core.profiledir
# email.os
# pygments.formatters
# prompt_toolkit.layout.abc
# prompt_toolkit.six
# backports.shutil_get_terminal_size.sys
# pywintypes
# IPython.utils.types
# tornado.platform
# _struct
# IPython.core.magics.pylab
# zmq.sugar.stopwatch
# concurrent.futures.weakref
# prompt_toolkit.filters.weakref
# ipywidgets.widgets.widget_controller
# uu
# IPython.core.functools
# dateutil.tz.bisect
# IPython.paths
# IPython.terminal.pygments
# jupyter_client.subprocess
# logging.time
# prompt_toolkit.filters.types
# ipykernel.ipython_genutils
# zmq.sugar.errno
# IPython.lib.imp
# logging.warnings
# IPython.tempfile
# multiprocessing.signal
# pygments.re
# dateutil.datetime
# jupyter_client.hashlib
# logging.codecs
# _random
# zmq.backend.cython.copy
# zmq.utils.zmq
# prompt_toolkit.layout.margins
# contextlib
# IPython.utils.time
# prompt_toolkit.layout.dimension
# concurrent.futures.thread
# IPython.lib.hashlib
# traitlets.warnings
# prompt_toolkit.key_binding.bindings.scroll
# IPython.utils.glob
# pkg_resources.extern.six.moves
# importlib.sys
# IPython.utils.importstring
# IPython.core.release
# IPython.lib.pretty
# gettext
# IPython.core.magics.IPython
# win32com.sys
# _abcoll
# prompt_toolkit.os
# jupyter_client.client
# getopt
# nt
# prompt_toolkit.layout.prompt
# wcwidth.wcwidth
# ipython_genutils.types
# genericpath
# stat
# jupyter_core
# pygments.lexers
# IPython.core.formatters
# IPython.warnings
# prompt_toolkit.collections
# time
# prompt_toolkit.styles.utils
# ipykernel.time
# zmq.sugar.threading
# concurrent
# email.Encoders
# ctypes.ctypes
# IPython.utils.functools
# pygments.style
# tornado.platform.windows
# IPython.core.itertools
# zmq.sugar.poll
# encodings.mbcs
# prompt_toolkit.layout
# traitlets.utils.importstring
# pkg_resources._vendor.types
# ipykernel.jsonutil
# win32com
# IPython.utils.signatures
# jupyter_client.blocking.time
# IPython.core.tempfile
# pythoncom
# colorama.re
# tornado.ioloop
# IPython.utils.py3compat
# traitlets.re

# %%
__main__
# Out:
# <module '__main__' (built-in)>

# %%
zmq.utils
# Out:
# <module 'zmq.utils' from 'C:\Anaconda2\lib\site-packages\zmq\utils\__init__.pyc'>

# %%
mds['zmq.utils']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-2966862a86e6> in <module>()
# ----> 1 mds['zmq.utils']
#
# KeyError: 'zmq.utils'

# %%
mds
# Out:
# {'a': 1}

# %%
globals()
# Out:
# {'In': ['',
#   u'import importlib\nmod = importlib.import_module(testName)',
#   u"import importlib\nmod = importlib.import_module('sys')",
#   u'mod.modules',
#   u'mod.modules.values()',
#   u'[m.__name__ for m in mod.modules]',
#   u'[m for m in mod.modules]',
#   u'[importlib.import_module(m) for m in mod.modules]',
#   u'[m for m in mod.modules]',
#   u'modules = [m for m in mod.modules]\nfor m in modules:\n    print m\n    importlib.import_module(m)',
#   u'modules = [m for m in mod.modules]\nfor m in modules:\n    print m\n    try:\n        importlib.import_module(m)\n    except Exception as e:\n        print e',
#   u'IPython.core.release',
#   u"mds = dict()\nmds['a'] = 1",
#   u'mds',
#   u'modules = [m for m in mod.modules]\nmds = dict()\nfor m in modules:\n    print m\n    try:\n        mds[m] = importlib.import_module(m)\n    except Exception as e:\n        print e',
#   u"mds['decorator']",
#   u'globals()'],
#  'Out': {3: {'email.MIMEAudio': <email.LazyImporter at 0x3c0d588>,
#    'IPython.core.error': <module 'IPython.core.error' from 'C:\Anaconda2\lib\site-packages\IPython\core\error.pyc'>,
#    'ipython_genutils.py3compat': <module 'ipython_genutils.py3compat' from 'C:\Anaconda2\lib\site-packages\ipython_genutils\py3compat.pyc'>,
#    'traitlets.config.sys': None,
#    'concurrent.futures.types': None,
#    'ipykernel.parentpoller': <module 'ipykernel.parentpoller' from 'C:\Anaconda2\lib\site-packages\ipykernel\parentpoller.pyc'>,
#    'traitlets.config.decorator': None,
#    'ctypes.os': None,
#    'IPython.terminal.pt_inputhooks.importlib': None,
#    'runpy': <module 'runpy' from 'C:\Anaconda2\lib\runpy.pyc'>,
#    'gc': <module 'gc' (built-in)>,
#    'ipykernel.os': None,
#    'prompt_toolkit.terminal.vt100_output': <module 'prompt_toolkit.terminal.vt100_output' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\terminal\vt100_output.pyc'>,
#    'email.iterators': <module 'email.iterators' from 'C:\Anaconda2\lib\email\iterators.pyc'>,
#    'prompt_toolkit.key_binding.six': None,
#    'win32com.os': None,
#    'pygments.filters': <module 'pygments.filters' from 'C:\Anaconda2\lib\site-packages\pygments\filters\__init__.pyc'>,
#    'IPython.utils.pprint': None,
#    'email.warnings': None,
#    'jupyter_client.blocking.channels': <module 'jupyter_client.blocking.channels' from 'C:\Anaconda2\lib\site-packages\jupyter_client\blocking\channels.pyc'>,
#    'ipykernel.kernelbase': <module 'ipykernel.kernelbase' from 'C:\Anaconda2\lib\site-packages\ipykernel\kernelbase.pyc'>,
#    'IPython.core.msvcrt': None,
#    'logging.weakref': None,
#    'traitlets.traitlets': <module 'traitlets.traitlets' from 'C:\Anaconda2\lib\site-packages\traitlets\traitlets.pyc'>,
#    'dateutil.tz.os': None,
#    'pprint': <module 'pprint' from 'C:\Anaconda2\lib\pprint.pyc'>,
#    'pkg_resources.extern.packaging.specifiers': <module 'pkg_resources._vendor.packaging.specifiers' from 'C:\Anaconda2\lib\site-packages\setuptools-27.2.0-py2.7.egg\pkg_resources\_vendor\packaging\specifiers.py'>,
#    'prompt_toolkit.key_binding.manager': <module 'prompt_toolkit.key_binding.manager' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\key_binding\manager.pyc'>,
#    'IPython.utils.simplegeneric': None,
#    'prompt_toolkit.key_binding.bindings.vi': <module 'prompt_toolkit.key_binding.bindings.vi' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\key_binding\bindings\vi.pyc'>,
#    'ipykernel.traitlets': None,
#    'IPython.core.magics.display': <module 'IPython.core.magics.display' from 'C:\Anaconda2\lib\site-packages\IPython\core\magics\display.pyc'>,
#    'colorama.ansi': <module 'colorama.ansi' from 'C:\Anaconda2\lib\site-packages\colorama\ansi.pyc'>,
#    'timeit': <module 'timeit' from 'C:\Anaconda2\lib\timeit.pyc'>,
#    'IPython.terminal.sys': None,
#    'string': <module 'string' from 'C:\Anaconda2\lib\string.pyc'>,
#    'prompt_toolkit.__future__': None,
#    'prompt_toolkit.layout.six': None,
#    'multiprocessing.threading': None,
#    'jupyter_client.blocking.__future__': None,
#    'IPython.utils.timing': <module 'IPython.utils.timing' from 'C:\Anaconda2\lib\site-packages\IPython\utils\timing.pyc'>,
#    'encodings.utf_8': <module 'encodings.utf_8' from 'C:\Anaconda2\lib\encodings\utf_8.pyc'>,
#    'email.codecs': None,
#    'email.quoprimime': <module 'email.quoprimime' from 'C:\Anaconda2\lib\email\quoprimime.pyc'>,
#    'IPython.terminal.embed': <module 'IPython.terminal.embed' from 'C:\Anaconda2\lib\site-packages\IPython\terminal\embed.pyc'>,
#    'zmq.utils.atexit': None,
#    'datetime': <module 'datetime' (built-in)>,
#    'ipykernel.errno': None,
#    'zmq.backend.cython.utils': <module 'zmq.backend.cython.utils' from 'C:\Anaconda2\lib\site-packages\zmq\backend\cython\utils.pyd'>,
#    'traitlets.six': None,
#    'ipython_genutils': <module 'ipython_genutils' from 'C:\Anaconda2\lib\site-packages\ipython_genutils\__init__.pyc'>,
#    'prompt_toolkit.eventloop.abc': None,
#    'array': <module 'array' (built-in)>,
#    'cmd': <module 'cmd' from 'C:\Anaconda2\lib\cmd.pyc'>,
#    'IPython.core.debugger': <module 'IPython.core.debugger' from 'C:\Anaconda2\lib\site-packages\IPython\core\debugger.pyc'>,
#    'concurrent.futures.collections': None,
#    'IPython.core.displayhook': <module 'IPython.core.displayhook' from 'C:\Anaconda2\lib\site-packages\IPython\core\displayhook.pyc'>,
#    'zmq.eventloop.Queue': None,
#    'IPython.lib.IPython': None,
#    'pygments.lexers.pygments': None,
#    'prompt_toolkit.styles.prompt_toolkit': None,
#    'shlex': <module 'shlex' from 'C:\Anaconda2\lib\shlex.pyc'>,
#    'zmq.backend.cython.zmq': None,
#    'IPython.core.ultratb': <module 'IPython.core.ultratb' from 'C:\Anaconda2\lib\site-packages\IPython\core\ultratb.pyc'>,
#    'prompt_toolkit.clipboard': <module 'prompt_toolkit.clipboard' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\clipboard\__init__.pyc'>,
#    'dis': <module 'dis' from 'C:\Anaconda2\lib\dis.pyc'>,
#    'prompt_toolkit.filters.utils': <module 'prompt_toolkit.filters.utils' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\filters\utils.pyc'>,
#    'zlib': <module 'zlib' (built-in)>,
#    'logging.threading': None,
#    'IPython.core.splitinput': <module 'IPython.core.splitinput' from 'C:\Anaconda2\lib\site-packages\IPython\core\splitinput.pyc'>,
#    'IPython.lib.types': None,
#    'pkg_resources._vendor.pprint': None,
#    'ipywidgets.widgets.domwidget': <module 'ipywidgets.widgets.domwidget' from 'C:\Anaconda2\lib\site-packages\ipywidgets\widgets\domwidget.pyc'>,
#    'pygments.styles.pygments': None,
#    'IPython.terminal.ipapp': <module 'IPython.terminal.ipapp' from 'C:\Anaconda2\lib\site-packages\IPython\terminal\ipapp.pyc'>,
#    'IPython.terminal.unicodedata': None,
#    'IPython.core.excolors': <module 'IPython.core.excolors' from 'C:\Anaconda2\lib\site-packages\IPython\core\excolors.pyc'>,
#    'ipykernel.datapub': <module 'ipykernel.datapub' from 'C:\Anaconda2\lib\site-packages\ipykernel\datapub.pyc'>,
#    'IPython.utils.tempfile': None,
#    'prompt_toolkit.layout.screen': <module 'prompt_toolkit.layout.screen' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\layout\screen.pyc'>,
#    'IPython.core.inspect': None,
#    'IPython.lib.getpass': None,
#    'abc': <module 'abc' from 'C:\Anaconda2\lib\abc.pyc'>,
#    'IPython.core.displaypub': <module 'IPython.core.displaypub' from 'C:\Anaconda2\lib\site-packages\IPython\core\displaypub.pyc'>,
#    'zmq.utils.sys': None,
#    'bdb': <module 'bdb' from 'C:\Anaconda2\lib\bdb.pyc'>,
#    'ipykernel._subprocess': None,
#    'ast': <module 'ast' from 'C:\Anaconda2\lib\ast.pyc'>,
#    'ipython_genutils.sys': None,
#    'ipykernel.copy_reg': None,
#    'IPython.core.mimetypes': None,
#    'traitlets.os': None,
#    'jupyter_client.blocking.client': <module 'jupyter_client.blocking.client' from 'C:\Anaconda2\lib\site-packages\jupyter_client\blocking\client.pyc'>,
#    'IPython.utils.io': <module 'IPython.utils.io' from 'C:\Anaconda2\lib\site-packages\IPython\utils\io.pyc'>,
#    'ntpath': <module 'ntpath' from 'C:\Anaconda2\lib\ntpath.pyc'>,
#    'UserDict': <module 'UserDict' from 'C:\Anaconda2\lib\UserDict.pyc'>,
#    'zmq.sugar.warnings': None,
#    'jupyter_client.adapter': <module 'jupyter_client.adapter' from 'C:\Anaconda2\lib\site-packages\jupyter_client\adapter.pyc'>,
#    'pygments.pkg_resources': None,
#    'IPython.utils.openpy': <module 'IPython.utils.openpy' from 'C:\Anaconda2\lib\site-packages\IPython\utils\openpy.pyc'>,
#    'IPython.core.alias': <module 'IPython.core.alias' from 'C:\Anaconda2\lib\site-packages\IPython\core\alias.pyc'>,
#    'inspect': <module 'inspect' from 'C:\Anaconda2\lib\inspect.pyc'>,
#    'ipykernel.warnings': None,
#    'IPython.core.datetime': None,
#    'dateutil.tz.tz': <module 'dateutil.tz.tz' from 'C:\Anaconda2\lib\site-packages\dateutil\tz\tz.pyc'>,
#    'prompt_toolkit.terminal': <module 'prompt_toolkit.terminal' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\terminal\__init__.pyc'>,
#    'ipython_genutils.re': None,
#    '_ctypes': <module '_ctypes' from 'C:\Anaconda2\DLLs\_ctypes.pyd'>,
#    'glob': <module 'glob' from 'C:\Anaconda2\lib\glob.pyc'>,
#    'exceptions': <module 'exceptions' (built-in)>,
#    'json.scanner': <module 'json.scanner' from 'C:\Anaconda2\lib\json\scanner.pyc'>,
#    'concurrent.futures.itertools': None,
#    'colorama.winterm': <module 'colorama.winterm' from 'C:\Anaconda2\lib\site-packages\colorama\winterm.pyc'>,
#    'jupyter_client.hmac': None,
#    'codecs': <module 'codecs' from 'C:\Anaconda2\lib\codecs.pyc'>,
#    'dateutil.warnings': None,
#    'zmq.utils.warnings': None,
#    'jupyter_client.blocking.functools': None,
#    'prompt_toolkit.clipboard.six': None,
#    'IPython.core.shadowns': <module 'IPython.core.shadowns' from 'C:\Anaconda2\lib\site-packages\IPython\core\shadowns.pyc'>,
#    'traitlets.config.loader': <module 'traitlets.config.loader' from 'C:\Anaconda2\lib\site-packages\traitlets\config\loader.pyc'>,
#    'ipykernel.__future__': None,
#    'IPython.core.magics.extension': <module 'IPython.core.magics.extension' from 'C:\Anaconda2\lib\site-packages\IPython\core\magics\extension.pyc'>,
#    'ipython_genutils.locale': None,
#    'traitlets.config.json': None,
#    'IPython.utils.shutil': None,
#    'StringIO': <module 'StringIO' from 'C:\Anaconda2\lib\StringIO.pyc'>,
#    'concurrent.futures.atexit': None,
#    'wcwidth': <module 'wcwidth' from 'C:\Anaconda2\lib\site-packages\wcwidth\__init__.pyc'>,
#    'colorama.win32': <module 'colorama.win32' from 'C:\Anaconda2\lib\site-packages\colorama\win32.pyc'>,
#    'weakref': <module 'weakref' from 'C:\Anaconda2\lib\weakref.pyc'>,
#    'prompt_toolkit.styles.__future__': None,
#    'traitlets': <module 'traitlets' from 'C:\Anaconda2\lib\site-packages\traitlets\__init__.pyc'>,
#    'ipywidgets.os': None,
#    'ipykernel.math': None,
#    'dateutil.tz.ctypes': None,
#    'IPython.core.display': <module 'IPython.core.display' from 'C:\Anaconda2\lib\site-packages\IPython\core\display.pyc'>,
#    'IPython.core.usage': <module 'IPython.core.usage' from 'C:\Anaconda2\lib\site-packages\IPython\core\usage.pyc'>,
#    'ipykernel.heartbeat': <module 'ipykernel.heartbeat' from 'C:\Anaconda2\lib\site-packages\ipykernel\heartbeat.pyc'>,
#    'IPython.terminal': <module 'IPython.terminal' from 'C:\Anaconda2\lib\site-packages\IPython\terminal\__init__.pyc'>,
#    'base64': <module 'base64' from 'C:\Anaconda2\lib\base64.pyc'>,
#    'jupyter_client.os': None,
#    '_sre': <module '_sre' (built-in)>,
#    'pygments.formatters.html': <module 'pygments.formatters.html' from 'C:\Anaconda2\lib\site-packages\pygments\formatters\html.pyc'>,
#    'email.FeedParser': <email.LazyImporter at 0x3c0d240>,
#    'ipykernel.iostream': <module 'ipykernel.iostream' from 'C:\Anaconda2\lib\site-packages\ipykernel\iostream.pyc'>,
#    'IPython.core.json': None,
#    'traitlets.types': None,
#    'sqlite3.dbapi2': <module 'sqlite3.dbapi2' from 'C:\Anaconda2\lib\sqlite3\dbapi2.pyc'>,
#    'IPython': <module 'IPython' from 'C:\Anaconda2\lib\site-packages\IPython\__init__.pyc'>,
#    'copy_reg': <module 'copy_reg' from 'C:\Anaconda2\lib\copy_reg.pyc'>,
#    'pkg_resources._vendor.datetime': None,
#    'prompt_toolkit.clipboard.prompt_toolkit': None,
#    'IPython.core.errno': None,
#    'IPython.core.subprocess': None,
#    'ctypes._ctypes': None,
#    '_heapq': <module '_heapq' (built-in)>,
#    'IPython.core.display_trap': <module 'IPython.core.display_trap' from 'C:\Anaconda2\lib\site-packages\IPython\core\display_trap.pyc'>,
#    'zmq.sugar.constants': <module 'zmq.sugar.constants' from 'C:\Anaconda2\lib\site-packages\zmq\sugar\constants.pyc'>,
#    'prompt_toolkit.key_binding.bindings.prompt_toolkit': None,
#    'zmq.backend.cython.time': None,
#    'binascii': <module 'binascii' (built-in)>,
#    'IPython.lib.contextlib': None,
#    'pygments.lexers.python': <module 'pygments.lexers.python' from 'C:\Anaconda2\lib\site-packages\pygments\lexers\python.pyc'>,
#    'email.MIMEMessage': <email.LazyImporter at 0x3c0d6a0>,
#    'IPython.core.logger': <module 'IPython.core.logger' from 'C:\Anaconda2\lib\site-packages\IPython\core\logger.pyc'>,
#    'email.sys': None,
#    'jupyter_client.manager': <module 'jupyter_client.manager' from 'C:\Anaconda2\lib\site-packages\jupyter_client\manager.pyc'>,
#    'tokenize': <module 'tokenize' from 'C:\Anaconda2\lib\tokenize.pyc'>,
#    'pygments.formatters.sys': None,
#    'IPython.core.StringIO': None,
#    'pkg_resources._vendor.six.moves.urllib': <module 'pkg_resources._vendor.six.moves.urllib' (built-in)>,
#    'email.MIMEText': <email.LazyImporter at 0x3c0d898>,
#    'IPython.core.magics.io': None,
#    'traitlets.utils.inspect': None,
#    'pkg_resources.extern.six.moves.urllib': <module 'pkg_resources._vendor.six.moves.urllib' (built-in)>,
#    'cPickle': <module 'cPickle' (built-in)>,
#    'jupyter_client.session': <module 'jupyter_client.session' from 'C:\Anaconda2\lib\site-packages\jupyter_client\session.pyc'>,
#    'ipykernel.comm.ipykernel': None,
#    'prompt_toolkit.pygments': None,
#    'IPython.core.magics.errno': None,
#    'jupyter_client.blocking.jupyter_client': None,
#    'IPython.utils.encoding': <module 'IPython.utils.encoding' from 'C:\Anaconda2\lib\site-packages\IPython\utils\encoding.pyc'>,
#    'zmq.utils.struct': None,
#    'IPython.core.ast': None,
#    'IPython.core.keyword': None,
#    'IPython.lib.os': None,
#    'prompt_toolkit.clipboard.base': <module 'prompt_toolkit.clipboard.base' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\clipboard\base.pyc'>,
#    'prompt_toolkit.styles.abc': None,
#    'prompt_toolkit.terminal.__future__': None,
#    'zmq.backend.cython.cPickle': None,
#    'IPython.core.getipython': <module 'IPython.core.getipython' from 'C:\Anaconda2\lib\site-packages\IPython\core\getipython.pyc'>,
#    'zmq.utils.garbage': <module 'zmq.utils.garbage' from 'C:\Anaconda2\lib\site-packages\zmq\utils\garbage.pyc'>,
#    'ipykernel.cPickle': None,
#    'prompt_toolkit.key_binding.input_processor': <module 'prompt_toolkit.key_binding.input_processor' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\key_binding\input_processor.pyc'>,
#    'unicodedata': <module 'unicodedata' from 'C:\Anaconda2\DLLs\unicodedata.pyd'>,
#    'zmq': <module 'zmq' from 'C:\Anaconda2\lib\site-packages\zmq\__init__.pyc'>,
#    'IPython.core.page': <module 'IPython.core.page' from 'C:\Anaconda2\lib\site-packages\IPython\core\page.pyc'>,
#    '_ast': <module '_ast' (built-in)>,
#    'IPython.utils.process': <module 'IPython.utils.process' from 'C:\Anaconda2\lib\site-packages\IPython\utils\process.pyc'>,
#    'jupyter_client.sys': None,
#    'IPython.utils.ctypes': None,
#    'jupyter_client.io': None,
#    'zmq.sugar.tracker': <module 'zmq.sugar.tracker' from 'C:\Anaconda2\lib\site-packages\zmq\sugar\tracker.pyc'>,
#    'jupyter_client.blocking.getpass': None,
#    'pkg_resources._vendor.copy': None,
#    'zmq.backend.cython.codecs': None,
#    'encodings.aliases': <module 'encodings.aliases' from 'C:\Anaconda2\lib\encodings\aliases.pyc'>,
#    'fnmatch': <module 'fnmatch' from 'C:\Anaconda2\lib\fnmatch.pyc'>,
#    'sre_parse': <module 'sre_parse' from 'C:\Anaconda2\lib\sre_parse.pyc'>,
#    'tornado.concurrent': <module 'tornado.concurrent' from 'C:\Anaconda2\lib\site-packages\tornado\concurrent.pyc'>,
#    'jupyter_core.version': <module 'jupyter_core.version' from 'C:\Anaconda2\lib\site-packages\jupyter_core\version.pyc'>,
#    'ipywidgets.widgets.ipykernel': None,
#    'numbers': <module 'numbers' from 'C:\Anaconda2\lib\numbers.pyc'>,
#    'pygments.regexopt': <module 'pygments.regexopt' from 'C:\Anaconda2\lib\site-packages\pygments\regexopt.pyc'>,
#    'zmq.sugar.version': <module 'zmq.sugar.version' from 'C:\Anaconda2\lib\site-packages\zmq\sugar\version.pyc'>,
#    'jupyter_client.launcher': <module 'jupyter_client.launcher' from 'C:\Anaconda2\lib\site-packages\jupyter_client\launcher.pyc'>,
#    'logging.cStringIO': None,
#    'encodings.cp1252': <module 'encodings.cp1252' from 'C:\Anaconda2\lib\encodings\cp1252.pyc'>,
#    'IPython.terminal.debugger': <module 'IPython.terminal.debugger' from 'C:\Anaconda2\lib\site-packages\IPython\terminal\debugger.pyc'>,
#    'pkg_resources._vendor.os': None,
#    'pkg_resources.extern.six': <module 'pkg_resources._vendor.six' from 'C:\Anaconda2\lib\site-packages\setuptools-27.2.0-py2.7.egg\pkg_resources\_vendor\six.py'>,
#    'prompt_toolkit.styles.six': None,
#    '_scandir': <module '_scandir' from 'C:\Anaconda2\lib\site-packages\_scandir.pyd'>,
#    'IPython.utils.shlex': None,
#    'IPython.core.magics.signal': None,
#    'ipykernel.comm.ipython_genutils': None,
#    'prompt_toolkit.key_binding.abc': None,
#    'traitlets.inspect': None,
#    'email.message': <module 'email.message' from 'C:\Anaconda2\lib\email\message.pyc'>,
#    'prompt_toolkit.eventloop.base': <module 'prompt_toolkit.eventloop.base' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\eventloop\base.pyc'>,
#    'ipykernel.zmq': None,
#    'IPython.utils.platform': None,
#    'strop': <module 'strop' (built-in)>,
#    'pygments.util': <module 'pygments.util' from 'C:\Anaconda2\lib\site-packages\pygments\util.pyc'>,
#    'jupyter_client.jupyter_client': None,
#    'IPython.core.history': <module 'IPython.core.history' from 'C:\Anaconda2\lib\site-packages\IPython\core\history.pyc'>,
#    'concurrent.futures.process': <module 'concurrent.futures.process' from 'C:\Anaconda2\lib\site-packages\concurrent\futures\process.pyc'>,
#    'six': <module 'six' from 'C:\Anaconda2\lib\site-packages\six.pyc'>,
#    'IPython.shutil': None,
#    'jupyter_client.connect': <module 'jupyter_client.connect' from 'C:\Anaconda2\lib\site-packages\jupyter_client\connect.pyc'>,
#    'ipython_genutils.textwrap': None,
#    'prompt_toolkit.abc': None,
#    'IPython.utils.ipstruct': <module 'IPython.utils.ipstruct' from 'C:\Anaconda2\lib\site-packages\IPython\utils\ipstruct.pyc'>,
#    'traitlets._version': <module 'traitlets._version' from 'C:\Anaconda2\lib\site-packages\traitlets\_version.pyc'>,
#    'dateutil.math': None,
#    'IPython.extensions.__future__': None,
#    'jupyter_client.jupyter_core': None,
#    'concurrent.pkgutil': None,
#    'ctypes.util': <module 'ctypes.util' from 'C:\Anaconda2\lib\ctypes\util.pyc'>,
#    'dateutil.relativedelta': <module 'dateutil.relativedelta' from 'C:\Anaconda2\lib\site-packages\dateutil\relativedelta.pyc'>,
#    'htmlentitydefs': <module 'htmlentitydefs' from 'C:\Anaconda2\lib\htmlentitydefs.pyc'>,
#    'zmq.utils.collections': None,
#    'zmq.backend.cython.threading': None,
#    'ipywidgets.widgets.widget_link': <module 'ipywidgets.widgets.widget_link' from 'C:\Anaconda2\lib\site-packages\ipywidgets\widgets\widget_link.pyc'>,
#    'jupyter_core.tempfile': None,
#    'ipywidgets.widgets.contextlib': None,
#    'jupyter_client.blocking': <module 'jupyter_client.blocking' from 'C:\Anaconda2\lib\site-packages\jupyter_client\blocking\__init__.pyc'>,
#    'jupyter_client.multikernelmanager': <module 'jupyter_client.multikernelmanager' from 'C:\Anaconda2\lib\site-packages\jupyter_client\multikernelmanager.pyc'>,
#    'codeop': <module 'codeop' from 'C:\Anaconda2\lib\codeop.pyc'>,
#    'email.parser': <module 'email.parser' from 'C:\Anaconda2\lib\email\parser.pyc'>,
#    'pygments.formatter': <module 'pygments.formatter' from 'C:\Anaconda2\lib\site-packages\pygments\formatter.pyc'>,
#    'os.path': <module 'ntpath' from 'C:\Anaconda2\lib\ntpath.pyc'>,
#    'IPython.core.magics.time': None,
#    'argparse': <module 'argparse' from 'C:\Anaconda2\lib\argparse.pyc'>,
#    'prompt_toolkit.eventloop.callbacks': <module 'prompt_toolkit.eventloop.callbacks' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\eventloop\callbacks.pyc'>,
#    'email.base64mime': <module 'email.base64mime' from 'C:\Anaconda2\lib\email\base64mime.pyc'>,
#    'simplegeneric': <module 'simplegeneric' from 'C:\Anaconda2\lib\site-packages\simplegeneric.pyc'>,
#    'IPython.core.payload': <module 'IPython.core.payload' from 'C:\Anaconda2\lib\site-packages\IPython\core\payload.pyc'>,
#    'marshal': <module 'marshal' (built-in)>,
#    '_weakrefset': <module '_weakrefset' from 'C:\Anaconda2\lib\_weakrefset.pyc'>,
#    'zmq.backend.select': <module 'zmq.backend.select' from 'C:\Anaconda2\lib\site-packages\zmq\backend\select.pyc'>,
#    'email.string': None,
#    'colorama.atexit': None,
#    'ipywidgets.widgets.widget': <module 'ipywidgets.widgets.widget' from 'C:\Anaconda2\lib\site-packages\ipywidgets\widgets\widget.pyc'>,
#    'traitlets.config.configurable': <module 'traitlets.config.configurable' from 'C:\Anaconda2\lib\site-packages\traitlets\config\configurable.pyc'>,
#    '_cython_0_25_1': <module '_cython_0_25_1' (built-in)>,
#    'IPython.core.traitlets': None,
#    'pygments.styles': <module 'pygments.styles' from 'C:\Anaconda2\lib\site-packages\pygments\styles\__init__.pyc'>,
#    'ipykernel.threading': None,
#    'win32com.shell.win32com': None,
#    'prompt_toolkit.io': None,
#    'pygments.pygments': None,
#    'functools': <module 'functools' from 'C:\Anaconda2\lib\functools.pyc'>,
#    'pythoncom.__univgw': <module 'pythoncom.__univgw' (built-in)>,
#    'prompt_toolkit.subprocess': None,
#    'sysconfig': <module 'sysconfig' from 'C:\Anaconda2\lib\sysconfig.pyc'>,
#    'json.encoder': <module 'json.encoder' from 'C:\Anaconda2\lib\json\encoder.pyc'>,
#    'email.MIMEImage': <email.LazyImporter at 0x3c0d630>,
#    'concurrent.futures.concurrent': None,
#    'prompt_toolkit.terminal.win32_input': <module 'prompt_toolkit.terminal.win32_input' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\terminal\win32_input.pyc'>,
#    'jupyter_client._version': <module 'jupyter_client._version' from 'C:\Anaconda2\lib\site-packages\jupyter_client\_version.pyc'>,
#    'sqlite3.collections': None,
#    'pygments.formatters.types': None,
#    'zmq.backend.cython.error': <module 'zmq.backend.cython.error' from 'C:\Anaconda2\lib\site-packages\zmq\backend\cython\error.pyd'>,
#    'dateutil.tz.time': None,
#    'prompt_toolkit.eventloop.__future__': None,
#    'uuid': <module 'uuid' from 'C:\Anaconda2\lib\uuid.pyc'>,
#    'jupyter_core.os': None,
#    'tempfile': <module 'tempfile' from 'C:\Anaconda2\lib\tempfile.pyc'>,
#    'prompt_toolkit.terminal.conemu_output': <module 'prompt_toolkit.terminal.conemu_output' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\terminal\conemu_output.pyc'>,
#    'win32com.shell': <module 'win32com.shell' from 'C:\Anaconda2\lib\site-packages\win32comext\shell\__init__.pyc'>,
#    'prompt_toolkit.tempfile': None,
#    'imp': <module 'imp' (built-in)>,
#    'pkg_resources._vendor': <module 'pkg_resources._vendor' from 'C:\Anaconda2\lib\site-packages\setuptools-27.2.0-py2.7.egg\pkg_resources\_vendor\__init__.py'>,
#    'prompt_toolkit.wcwidth': None,
#    'multiprocessing.os': None,
#    'jupyter_core.sys': None,
#    'IPython.utils.tempdir': <module 'IPython.utils.tempdir' from 'C:\Anaconda2\lib\site-packages\IPython\utils\tempdir.pyc'>,
#    'ipywidgets.widgets.__future__': None,
#    'multiprocessing.itertools': None,
#    'backports.shutil_get_terminal_size.collections': None,
#    'enum.sys': None,
#    'zmq.libzmq': <module 'zmq.libzmq' from 'C:\Anaconda2\lib\site-packages\zmq\libzmq.pyd'>,
#    'jupyter_client.random': None,
#    'traitlets.utils.sentinel': <module 'traitlets.utils.sentinel' from 'C:\Anaconda2\lib\site-packages\traitlets\utils\sentinel.pyc'>,
#    'IPython.core.magics.logging': <module 'IPython.core.magics.logging' from 'C:\Anaconda2\lib\site-packages\IPython\core\magics\logging.pyc'>,
#    'prompt_toolkit.ctypes': None,
#    'zmq.zmq': None,
#    'email.calendar': None,
#    'prompt_toolkit.input': <module 'prompt_toolkit.input' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\input.pyc'>,
#    'pkg_resources._vendor.six': <module 'pkg_resources._vendor.six' from 'C:\Anaconda2\lib\site-packages\setuptools-27.2.0-py2.7.egg\pkg_resources\_vendor\six.py'>,
#    'zmq.eventloop.tornado': None,
#    'email.email': None,
#    'IPython.core.traceback': None,
#    'IPython.utils._tokenize_py2': <module 'IPython.utils._tokenize_py2' from 'C:\Anaconda2\lib\site-packages\IPython\utils\_tokenize_py2.pyc'>,
#    'IPython.core.__main__': None,
#    'ipython_genutils._version': <module 'ipython_genutils._version' from 'C:\Anaconda2\lib\site-packages\ipython_genutils\_version.pyc'>,
#    'prompt_toolkit.layout.mouse_handlers': <module 'prompt_toolkit.layout.mouse_handlers' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\layout\mouse_handlers.pyc'>,
#    'prompt_toolkit.types': None,
#    'email.urllib': None,
#    'concurrent.futures.logging': None,
#    'win32com.gen_py': <module 'win32com.gen_py' (built-in)>,
#    'decorator': <module 'decorator' from 'C:\Anaconda2\lib\site-packages\decorator.pyc'>,
#    'IPython.core.zipimport': None,
#    'pygments.lexers.sys': None,
#    'pygments.unistring': <module 'pygments.unistring' from 'C:\Anaconda2\lib\site-packages\pygments\unistring.pyc'>,
#    'IPython.terminal.interactiveshell': <module 'IPython.terminal.interactiveshell' from 'C:\Anaconda2\lib\site-packages\IPython\terminal\interactiveshell.pyc'>,
#    'IPython.extensions.traitlets': None,
#    'zmq.backend.cython.context': <module 'zmq.backend.cython.context' from 'C:\Anaconda2\lib\site-packages\zmq\backend\cython\context.pyd'>,
#    'ipywidgets.widgets.itertools': None,
#    'ipykernel.ipykernel': None,
#    'IPython.core.warnings': None,
#    'IPython.utils.imp': None,
#    'logging.handlers': <module 'logging.handlers' from 'C:\Anaconda2\lib\logging\handlers.pyc'>,
#    'dateutil.tz.datetime': None,
#    'token': <module 'token' from 'C:\Anaconda2\lib\token.pyc'>,
#    'prompt_toolkit.key_binding.digraphs': <module 'prompt_toolkit.key_binding.digraphs' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\key_binding\digraphs.pyc'>,
#    'prompt_toolkit.auto_suggest': <module 'prompt_toolkit.auto_suggest' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\auto_suggest.pyc'>,
#    'prompt_toolkit.buffer': <module 'prompt_toolkit.buffer' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\buffer.pyc'>,
#    'dateutil.operator': None,
#    'IPython.testing.sys': None,
#    'pygments.formatters.os': None,
#    'IPython.utils.warnings': None,
#    'IPython.core.magics.gc': None,
#    'dateutil.tz.struct': None,
#    'cStringIO': <module 'cStringIO' (built-in)>,
#    'IPython.utils.errno': None,
#    'backports.shutil_get_terminal_size.struct': None,
#    'IPython.core.io': None,
#    'IPython.terminal.pt_inputhooks': <module 'IPython.terminal.pt_inputhooks' from 'C:\Anaconda2\lib\site-packages\IPython\terminal\pt_inputhooks\__init__.pyc'>,
#    'IPython.core.magics.namespace': <module 'IPython.core.magics.namespace' from 'C:\Anaconda2\lib\site-packages\IPython\core\magics\namespace.pyc'>,
#    'traitlets.config.copy': None,
#    'ipywidgets.widgets.widget_color': <module 'ipywidgets.widgets.widget_color' from 'C:\Anaconda2\lib\site-packages\ipywidgets\widgets\widget_color.pyc'>,
#    'traitlets.utils.ipython_genutils': None,
#    'zmq.sugar.frame': <module 'zmq.sugar.frame' from 'C:\Anaconda2\lib\site-packages\zmq\sugar\frame.pyc'>,
#    'multiprocessing.process': <module 'multiprocessing.process' from 'C:\Anaconda2\lib\multiprocessing\process.pyc'>,
#    'pkg_resources.extern.packaging.requirements': <module 'pkg_resources._vendor.packaging.requirements' from 'C:\Anaconda2\lib\site-packages\setuptools-27.2.0-py2.7.egg\pkg_resources\_vendor\packaging\requirements.py'>,
#    'prompt_toolkit.terminal.win32_output': <module 'prompt_toolkit.terminal.win32_output' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\terminal\win32_output.pyc'>,
#    'encodings': <module 'encodings' from 'C:\Anaconda2\lib\encodings\__init__.pyc'>,
#    'IPython.core.magics.history': <module 'IPython.core.magics.history' from 'C:\Anaconda2\lib\site-packages\IPython\core\magics\history.pyc'>,
#    'IPython.core.__future__': None,
#    'zmq.utils.strtypes': <module 'zmq.utils.strtypes' from 'C:\Anaconda2\lib\site-packages\zmq\utils\strtypes.pyc'>,
#    'prompt_toolkit.layout.toolbars': <module 'prompt_toolkit.layout.toolbars' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\layout\toolbars.pyc'>,
#    'ipykernel.comm.uuid': None,
#    'prompt_toolkit.styles.pygments': None,
#    'IPython.core.interactiveshell': <module 'IPython.core.interactiveshell' from 'C:\Anaconda2\lib\site-packages\IPython\core\interactiveshell.pyc'>,
#    'ipywidgets.widgets.widget_core': <module 'ipywidgets.widgets.widget_core' from 'C:\Anaconda2\lib\site-packages\ipywidgets\widgets\widget_core.pyc'>,
#    'traitlets.ipython_genutils': None,
#    'IPython.core.operator': None,
#    'IPython.core.crashhandler': <module 'IPython.core.crashhandler' from 'C:\Anaconda2\lib\site-packages\IPython\core\crashhandler.pyc'>,
#    'IPython.utils': <module 'IPython.utils' from 'C:\Anaconda2\lib\site-packages\IPython\utils\__init__.pyc'>,
#    '_subprocess': <module '_subprocess' (built-in)>,
#    'prompt_toolkit.layout.time': None,
#    'prompt_toolkit.threading': None,
#    'pkg_resources._vendor.packaging.__about__': <module 'pkg_resources._vendor.packaging.__about__' from 'C:\Anaconda2\lib\site-packages\setuptools-27.2.0-py2.7.egg\pkg_resources\_vendor\packaging\__about__.py'>,
#    're': <module 're' from 'C:\Anaconda2\lib\re.pyc'>,
#    'pygments.filters.re': None,
#    'jupyter_client.warnings': None,
#    'email.quopri': None,
#    'IPython.utils.capture': <module 'IPython.utils.capture' from 'C:\Anaconda2\lib\site-packages\IPython\utils\capture.pyc'>,
#    'pkg_resources._vendor.__builtin__': None,
#    'ipykernel.ipkernel': <module 'ipykernel.ipkernel' from 'C:\Anaconda2\lib\site-packages\ipykernel\ipkernel.pyc'>,
#    'sqlite3.time': None,
#    'dateutil._common': <module 'dateutil._common' from 'C:\Anaconda2\lib\site-packages\dateutil\_common.pyc'>,
#    'math': <module 'math' (built-in)>,
#    'IPython.core.IPython': None,
#    'pygments.formatters.fnmatch': None,
#    'wcwidth.__future__': None,
#    'ipykernel.comm.manager': <module 'ipykernel.comm.manager' from 'C:\Anaconda2\lib\site-packages\ipykernel\comm\manager.pyc'>,
#    'IPython.core.importlib': None,
#    'ipython_genutils.errno': None,
#    'dateutil.tz.six': None,
#    'IPython.lib.sys': None,
#    'prompt_toolkit.interface': <module 'prompt_toolkit.interface' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\interface.pyc'>,
#    'email.re': None,
#    'zmq.utils.constant_names': <module 'zmq.utils.constant_names' from 'C:\Anaconda2\lib\site-packages\zmq\utils\constant_names.pyc'>,
#    'prompt_toolkit.key_binding.bindings.six': None,
#    'ctypes.struct': None,
#    'IPython.utils.colorable': <module 'IPython.utils.colorable' from 'C:\Anaconda2\lib\site-packages\IPython\utils\colorable.pyc'>,
#    'ipykernel.ctypes': None,
#    'ipywidgets.widgets.IPython': None,
#    'prompt_toolkit.filters': <module 'prompt_toolkit.filters' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\filters\__init__.pyc'>,
#    '_locale': <module '_locale' (built-in)>,
#    'IPython.core.logging': None,
#    'logging': <module 'logging' from 'C:\Anaconda2\lib\logging\__init__.pyc'>,
#    'prompt_toolkit.enums': <module 'prompt_toolkit.enums' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\enums.pyc'>,
#    'thread': <module 'thread' (built-in)>,
#    'ipywidgets.widgets.interaction': <module 'ipywidgets.widgets.interaction' from 'C:\Anaconda2\lib\site-packages\ipywidgets\widgets\interaction.pyc'>,
#    'prompt_toolkit.eventloop': <module 'prompt_toolkit.eventloop' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\eventloop\__init__.pyc'>,
#    'traceback': <module 'traceback' from 'C:\Anaconda2\lib\traceback.pyc'>,
#    'ipykernel.signal': None,
#    'multiprocessing': <module 'multiprocessing' from 'C:\Anaconda2\lib\multiprocessing\__init__.pyc'>,
#    'concurrent.futures.time': None,
#    'IPython.core.copy': None,
#    'IPython.core.builtin_trap': <module 'IPython.core.builtin_trap' from 'C:\Anaconda2\lib\site-packages\IPython\core\builtin_trap.pyc'>,
#    'zmq.backend.platform': None,
#    'IPython.utils.coloransi': <module 'IPython.utils.coloransi' from 'C:\Anaconda2\lib\site-packages\IPython\utils\coloransi.pyc'>,
#    'multiprocessing.util': <module 'multiprocessing.util' from 'C:\Anaconda2\lib\multiprocessing\util.pyc'>,
#    'colorama.os': None,
#    'pkg_resources._vendor.packaging.markers': <module 'pkg_resources._vendor.packaging.markers' from 'C:\Anaconda2\lib\site-packages\setuptools-27.2.0-py2.7.egg\pkg_resources\_vendor\packaging\markers.py'>,
#    'pkg_resources._vendor.packaging.version': <module 'pkg_resources._vendor.packaging.version' from 'C:\Anaconda2\lib\site-packages\setuptools-27.2.0-py2.7.egg\pkg_resources\_vendor\packaging\version.py'>,
#    'ipywidgets.widgets.widget_layout': <module 'ipywidgets.widgets.widget_layout' from 'C:\Anaconda2\lib\site-packages\ipywidgets\widgets\widget_layout.pyc'>,
#    'prompt_toolkit.filters.six': None,
#    '_collections': <module '_collections' (built-in)>,
#    'prompt_toolkit.mouse_events': <module 'prompt_toolkit.mouse_events' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\mouse_events.pyc'>,
#    'ipykernel.jupyter_core': None,
#    'dateutil.re': None,
#    'prompt_toolkit.key_binding.bindings.__future__': None,
#    'traitlets.config.ast': None,
#    'multiprocessing.sys': None,
#    'ipykernel.uuid': None,
#    'ipywidgets.widgets.widget_button': <module 'ipywidgets.widgets.widget_button' from 'C:\Anaconda2\lib\site-packages\ipywidgets\widgets\widget_button.pyc'>,
#    'ipywidgets.IPython': None,
#    'pygments.filter': <module 'pygments.filter' from 'C:\Anaconda2\lib\site-packages\pygments\filter.pyc'>,
#    'email.Errors': <email.LazyImporter at 0x3c0d208>,
#    'IPython.utils.locale': None,
#    'ctypes.sys': None,
#    'IPython.core.magics.config': <module 'IPython.core.magics.config' from 'C:\Anaconda2\lib\site-packages\IPython\core\magics\config.pyc'>,
#    'pygments.lexers.__future__': None,
#    'posixpath': <module 'posixpath' from 'C:\Anaconda2\lib\posixpath.pyc'>,
#    'jupyter_client.channels': <module 'jupyter_client.channels' from 'C:\Anaconda2\lib\site-packages\jupyter_client\channels.pyc'>,
#    'pkg_resources._vendor.packaging._compat': <module 'pkg_resources._vendor.packaging._compat' from 'C:\Anaconda2\lib\site-packages\setuptools-27.2.0-py2.7.egg\pkg_resources\_vendor\packaging\_compat.py'>,
#    'email.cStringIO': None,
#    'IPython.utils._sysinfo': <module 'IPython.utils._sysinfo' from 'C:\Anaconda2\lib\site-packages\IPython\utils\_sysinfo.pyc'>,
#    'prompt_toolkit.filters.cli': <module 'prompt_toolkit.filters.cli' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\filters\cli.pyc'>,
#    'traitlets.logging': None,
#    'colorama.contextlib': None,
#    'zmq.utils.os': None,
#    'types': <module 'types' from 'C:\Anaconda2\lib\types.pyc'>,
#    'zmq.backend.cython._device': <module 'zmq.backend.cython._device' from 'C:\Anaconda2\lib\site-packages\zmq\backend\cython\_device.pyd'>,
#    'prompt_toolkit.utils': <module 'prompt_toolkit.utils' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\utils.pyc'>,
#    'prompt_toolkit.clipboard.in_memory': <module 'prompt_toolkit.clipboard.in_memory' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\clipboard\in_memory.pyc'>,
#    'IPython.core.linecache': None,
#    'ipywidgets.widgets.widget_string': <module 'ipywidgets.widgets.widget_string' from 'C:\Anaconda2\lib\site-packages\ipywidgets\widgets\widget_string.pyc'>,
#    '_win32sysloader': <module '_win32sysloader' from 'C:\Anaconda2\lib\site-packages\win32\_win32sysloader.pyd'>,
#    'json._json': None,
#    'ipykernel.jupyter_client': None,
#    '_codecs': <module '_codecs' (built-in)>,
#    'traitlets.contextlib': None,
#    'ipykernel.comm.sys': None,
#    'IPython.core.unicodedata': None,
#    'enum.collections': None,
#    'json.sys': None,
#    'win32com.win32api': None,
#    'IPython.utils.os': None,
#    'IPython.extensions.inspect': None,
#    'concurrent.futures.multiprocessing': None,
#    'pygments.time': None,
#    'zmq.eventloop.ioloop': <module 'zmq.eventloop.ioloop' from 'C:\Anaconda2\lib\site-packages\zmq\eventloop\ioloop.pyc'>,
#    'copy': <module 'copy' from 'C:\Anaconda2\lib\copy.pyc'>,
#    'ipykernel.datetime': None,
#    'prompt_toolkit.styles.collections': None,
#    'ipykernel.comm.logging': None,
#    'ipython_genutils.shutil': None,
#    'hashlib': <module 'hashlib' from 'C:\Anaconda2\lib\hashlib.pyc'>,
#    'prompt_toolkit': <module 'prompt_toolkit' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\__init__.pyc'>,
#    'email.errors': <module 'email.errors' from 'C:\Anaconda2\lib\email\errors.pyc'>,
#    'keyword': <module 'keyword' from 'C:\Anaconda2\lib\keyword.pyc'>,
#    'ipython_genutils.random': None,
#    'pkg_resources._vendor.packaging': <module 'pkg_resources._vendor.packaging' from 'C:\Anaconda2\lib\site-packages\setuptools-27.2.0-py2.7.egg\pkg_resources\_vendor\packaging\__init__.py'>,
#    'IPython.extensions.IPython': None,
#    'ipywidgets.widgets.sys': None,
#    'IPython.core.hashlib': None,
#    'ipywidgets.widgets.widget_output': <module 'ipywidgets.widgets.widget_output' from 'C:\Anaconda2\lib\site-packages\ipywidgets\widgets\widget_output.pyc'>,
#    'pygments.lexers.fnmatch': None,
#    'prompt_toolkit.terminal.ctypes': None,
#    'IPython.utils.generics': <module 'IPython.utils.generics' from 'C:\Anaconda2\lib\site-packages\IPython\utils\generics.pyc'>,
#    'ipykernel.connect': <module 'ipykernel.connect' from 'C:\Anaconda2\lib\site-packages\ipykernel\connect.pyc'>,
#    'backports.shutil_get_terminal_size.os': None,
#    'prompt_toolkit.layout.collections': None,
#    'sre_compile': <module 'sre_compile' from 'C:\Anaconda2\lib\sre_compile.pyc'>,
#    'ipykernel': <module 'ipykernel' from 'C:\Anaconda2\lib\site-packages\ipykernel\__init__.pyc'>,
#    '_hashlib': <module '_hashlib' from 'C:\Anaconda2\DLLs\_hashlib.pyd'>,
#    'prompt_toolkit.layout.utils': <module 'prompt_toolkit.layout.utils' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\layout\utils.pyc'>,
#    'IPython.utils.ulinecache': <module 'IPython.utils.ulinecache' from 'C:\Anaconda2\lib\site-packages\IPython\utils\ulinecache.pyc'>,
#    'zmq.eventloop.cPickle': None,
#    'IPython.core.magics.code': <module 'IPython.core.magics.code' from 'C:\Anaconda2\lib\site-packages\IPython\core\magics\code.pyc'>,
#    'IPython.core.sqlite3': None,
#    'IPython.core.bdb': None,
#    'logging.collections': None,
#    'IPython.core.threading': None,
#    'email.base64': None,
#    'pygments.__future__': None,
#    '__main__': <module '__main__' (built-in)>,
#    'colorama.initialise': <module 'colorama.initialise' from 'C:\Anaconda2\lib\site-packages\colorama\initialise.pyc'>,
#    'multiprocessing.atexit': None,
#    'ipykernel.itertools': None,
#    'zmq.backend.cython.message': <module 'zmq.backend.cython.message' from 'C:\Anaconda2\lib\site-packages\zmq\backend\cython\message.pyd'>,
#    'prompt_toolkit.string': None,
#    'prompt_toolkit.layout.re': None,
#    'IPython.extensions.textwrap': None,
#    'prompt_toolkit.layout.__future__': None,
#    'ipykernel.binascii': None,
#    'dateutil.parser': <module 'dateutil.parser' from 'C:\Anaconda2\lib\site-packages\dateutil\parser.pyc'>,
#    'prompt_toolkit.token': <module 'prompt_toolkit.token' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\token.pyc'>,
#    'IPython.utils.terminal': <module 'IPython.utils.terminal' from 'C:\Anaconda2\lib\site-packages\IPython\utils\terminal.pyc'>,
#    'jupyter_client.ipython_genutils': None,
#    'encodings.codecs': None,
#    'ipywidgets.widgets.widget_selection': <module 'ipywidgets.widgets.widget_selection' from 'C:\Anaconda2\lib\site-packages\ipywidgets\widgets\widget_selection.pyc'>,
#    'ipywidgets': <module 'ipywidgets' from 'C:\Anaconda2\lib\site-packages\ipywidgets\__init__.pyc'>,
#    'IPython.utils.__builtin__': None,
#    'IPython.terminal.os': None,
#    'IPython.lib.threading': None,
#    'zmq.utils.jsonapi': <module 'zmq.utils.jsonapi' from 'C:\Anaconda2\lib\site-packages\zmq\utils\jsonapi.pyc'>,
#    'email.MIMEMultipart': <email.LazyImporter at 0x3c0d748>,
#    'pkg_resources._vendor.win32com': None,
#    'ipywidgets.widgets.datetime': None,
#    'IPython.core.completer': <module 'IPython.core.completer' from 'C:\Anaconda2\lib\site-packages\IPython\core\completer.pyc'>,
#    'ipykernel.base64': None,
#    '_ssl': <module '_ssl' from 'C:\Anaconda2\DLLs\_ssl.pyd'>,
#    'ipykernel.types': None,
#    'IPython.utils.sys': None,
#    'IPython.utils.re': None,
#    'tornado': <module 'tornado' from 'C:\Anaconda2\lib\site-packages\tornado\__init__.pyc'>,
#    'IPython.lib.clipboard': <module 'IPython.lib.clipboard' from 'C:\Anaconda2\lib\site-packages\IPython\lib\clipboard.pyc'>,
#    'encodings.ascii': <module 'encodings.ascii' from 'C:\Anaconda2\lib\encodings\ascii.pyc'>,
#    'ipykernel.getpass': None,
#    'IPython.utils.inspect': None,
#    'zmq.backend.cython.sys': None,
#    'IPython.core.base64': None,
#    'pkg_resources.extern.appdirs': <module 'pkg_resources._vendor.appdirs' from 'C:\Anaconda2\lib\site-packages\setuptools-27.2.0-py2.7.egg\pkg_resources\_vendor\appdirs.py'>,
#    'colorama': <module 'colorama' from 'C:\Anaconda2\lib\site-packages\colorama\__init__.pyc'>,
#    '_sqlite3': <module '_sqlite3' from 'C:\Anaconda2\DLLs\_sqlite3.pyd'>,
#    'ipython_genutils.text': <module 'ipython_genutils.text' from 'C:\Anaconda2\lib\site-packages\ipython_genutils\text.pyc'>,
#    'IPython.core.shellapp': <module 'IPython.core.shellapp' from 'C:\Anaconda2\lib\site-packages\IPython\core\shellapp.pyc'>,
#    'email.feedparser': <module 'email.feedparser' from 'C:\Anaconda2\lib\email\feedparser.pyc'>,
#    'email.MIMEBase': <email.LazyImporter at 0x3c0d5f8>,
#    'prompt_toolkit.selection': <module 'prompt_toolkit.selection' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\selection.pyc'>,
#    'plistlib': <module 'plistlib' from 'C:\Anaconda2\lib\plistlib.pyc'>,
#    'multiprocessing._multiprocessing': None,
#    'concurrent.futures.sys': None,
#    'pygments.modeline': <module 'pygments.modeline' from 'C:\Anaconda2\lib\site-packages\pygments\modeline.pyc'>,
#    'pkg_resources._vendor.collections': None,
#    'IPython.utils.wildcard': <module 'IPython.utils.wildcard' from 'C:\Anaconda2\lib\site-packages\IPython\utils\wildcard.pyc'>,
#    'IPython.core.extensions': <module 'IPython.core.extensions' from 'C:\Anaconda2\lib\site-packages\IPython\core\extensions.pyc'>,
#    'IPython.utils.tokenutil': <module 'IPython.utils.tokenutil' from 'C:\Anaconda2\lib\site-packages\IPython\utils\tokenutil.pyc'>,
#    '_io': <module '_io' (built-in)>,
#    'linecache': <module 'linecache' from 'C:\Anaconda2\lib\linecache.pyc'>,
#    '_strptime': <module '_strptime' from 'C:\Anaconda2\lib\_strptime.pyc'>,
#    'ipywidgets.widgets.trait_types': <module 'ipywidgets.widgets.trait_types' from 'C:\Anaconda2\lib\site-packages\ipywidgets\widgets\trait_types.pyc'>,
#    'IPython.core.compilerop': <module 'IPython.core.compilerop' from 'C:\Anaconda2\lib\site-packages\IPython\core\compilerop.pyc'>,
#    'ipykernel.comm': <module 'ipykernel.comm' from 'C:\Anaconda2\lib\site-packages\ipykernel\comm\__init__.pyc'>,
#    'jupyter_client.zmq': None,
#    'hmac': <module 'hmac' from 'C:\Anaconda2\lib\hmac.pyc'>,
#    'tornado.platform.interface': <module 'tornado.platform.interface' from 'C:\Anaconda2\lib\site-packages\tornado\platform\interface.pyc'>,
#    'scandir': <module 'scandir' from 'C:\Anaconda2\lib\site-packages\scandir.pyc'>,
#    'prompt_toolkit.terminal.six': None,
#    'dateutil.collections': None,
#    'prompt_toolkit.key_binding.bindings.named_commands': <module 'prompt_toolkit.key_binding.bindings.named_commands' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\key_binding\bindings\named_commands.pyc'>,
#    '_multiprocessing': <module '_multiprocessing' from 'C:\Anaconda2\DLLs\_multiprocessing.pyd'>,
#    'ipywidgets.widgets.traitlets': None,
#    'IPython.core.magics.osm': <module 'IPython.core.magics.osm' from 'C:\Anaconda2\lib\site-packages\IPython\core\magics\osm.pyc'>,
#    'jupyter_client.json': None,
#    'random': <module 'random' from 'C:\Anaconda2\lib\random.pyc'>,
#    '_bisect': <module '_bisect' (built-in)>,
#    'zmq.sugar.context': <module 'zmq.sugar.context' from 'C:\Anaconda2\lib\site-packages\zmq\sugar\context.pyc'>,
#    'subprocess': <module 'subprocess' from 'C:\Anaconda2\lib\subprocess.pyc'>,
#    'IPython.extensions.storemagic': <module 'IPython.extensions.storemagic' from 'C:\Anaconda2\lib\site-packages\IPython\extensions\storemagic.pyc'>,
#    'prompt_toolkit.key_binding.weakref': None,
#    'prompt_toolkit.key_binding.vi_state': <module 'prompt_toolkit.key_binding.vi_state' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\key_binding\vi_state.pyc'>,
#    'pygments.operator': None,
#    'logging.os': None,
#    'ctypes._endian': <module 'ctypes._endian' from 'C:\Anaconda2\lib\ctypes\_endian.pyc'>,
#    'encodings.encodings': None,
#    'ipykernel.numbers': None,
#    'colorama.ansitowin32': <module 'colorama.ansitowin32' from 'C:\Anaconda2\lib\site-packages\colorama\ansitowin32.pyc'>,
#    'pygments.formatters._mapping': <module 'pygments.formatters._mapping' from 'C:\Anaconda2\lib\site-packages\pygments\formatters\_mapping.pyc'>,
#    'logging.stat': None,
#    'email.time': None,
#    'importlib': <module 'importlib' from 'C:\Anaconda2\lib\importlib\__init__.pyc'>,
#    'prompt_toolkit.styles.from_pygments': <module 'prompt_toolkit.styles.from_pygments' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\styles\from_pygments.pyc'>,
#    'IPython.core.magic': <module 'IPython.core.magic' from 'C:\Anaconda2\lib\site-packages\IPython\core\magic.pyc'>,
#    'ipywidgets.widgets.ipython_genutils': None,
#    'zmq.utils.threading': None,
#    'IPython.utils.dir2': <module 'IPython.utils.dir2' from 'C:\Anaconda2\lib\site-packages\IPython\utils\dir2.pyc'>,
#    '_json': <module '_json' (built-in)>,
#    'prompt_toolkit.key_binding.bindings.basic': <module 'prompt_toolkit.key_binding.bindings.basic' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\key_binding\bindings\basic.pyc'>,
#    'pkg_resources._vendor.warnings': None,
#    'ipykernel.logging': None,
#    'traitlets.config.argparse': None,
#    'ipython_genutils.importstring': <module 'ipython_genutils.importstring' from 'C:\Anaconda2\lib\site-packages\ipython_genutils\importstring.pyc'>,
#    'jupyter_client.blocking.traitlets': None,
#    'logging.thread': None,
#    'cProfile': <module 'cProfile' from 'C:\Anaconda2\lib\cProfile.pyc'>,
#    'prompt_toolkit.styles.defaults': <module 'prompt_toolkit.styles.defaults' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\styles\defaults.pyc'>,
#    'prompt_toolkit.buffer_mapping': <module 'prompt_toolkit.buffer_mapping' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\buffer_mapping.pyc'>,
#    'prompt_toolkit.history': <module 'prompt_toolkit.history' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\history.pyc'>,
#    'IPython.lib.re': None,
#    'pathlib2': <module 'pathlib2' from 'C:\Anaconda2\lib\site-packages\pathlib2.pyc'>,
#    'pygments.sys': None,
#    'prompt_toolkit.styles': <module 'prompt_toolkit.styles' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\styles\__init__.pyc'>,
#    'concurrent.futures.threading': None,
#    'zipfile': <module 'zipfile' from 'C:\Anaconda2\lib\zipfile.pyc'>,
#    'repr': <module 'repr' from 'C:\Anaconda2\lib\repr.pyc'>,
#    'ipykernel.traceback': None,
#    'ssl': <module 'ssl' from 'C:\Anaconda2\lib\ssl.pyc'>,
#    'traitlets.config.__future__': None,
#    'prompt_toolkit.reactive': <module 'prompt_toolkit.reactive' from 'C:\Anaconda2\lib\site-packages\prompt_toolkit\reactive.pyc'>,
#    'ipywidgets.widgets.widget_image': <module 'ipywidgets.widgets.widget_image' from 'C:\Anaconda2\lib\site-packages\ipywidgets\widgets\widget_image.pyc'>,
#    'ipython_genutils.platform': None,
#    'prompt_toolkit.terminal.msvcrt': None,
#    'ipywidgets.widgets.numbers': None,
# ...
#   'email.quopri',
#   'IPython.utils.capture',
#   'pkg_resources._vendor.__builtin__',
#   'ipykernel.ipkernel',
#   'sqlite3.time',
#   'dateutil._common',
#   'math',
#   'IPython.core.IPython',
#   'pygments.formatters.fnmatch',
#   'wcwidth.__future__',
#   'ipykernel.comm.manager',
#   'IPython.core.importlib',
#   'ipython_genutils.errno',
#   'dateutil.tz.six',
#   'IPython.lib.sys',
#   'prompt_toolkit.interface',
#   'email.re',
#   'zmq.utils.constant_names',
#   'prompt_toolkit.key_binding.bindings.six',
#   'ctypes.struct',
#   'IPython.utils.colorable',
#   'ipykernel.ctypes',
#   'ipywidgets.widgets.IPython',
#   'prompt_toolkit.filters',
#   '_locale',
#   'IPython.core.logging',
#   'logging',
#   'prompt_toolkit.enums',
#   'thread',
#   'ipywidgets.widgets.interaction',
#   'prompt_toolkit.eventloop',
#   'traceback',
#   'ipykernel.signal',
#   'multiprocessing',
#   'concurrent.futures.time',
#   'IPython.core.copy',
#   'IPython.core.builtin_trap',
#   'zmq.backend.platform',
#   'IPython.utils.coloransi',
#   'multiprocessing.util',
#   'colorama.os',
#   'pkg_resources._vendor.packaging.markers',
#   'pkg_resources._vendor.packaging.version',
#   'ipywidgets.widgets.widget_layout',
#   'prompt_toolkit.filters.six',
#   '_collections',
#   'prompt_toolkit.mouse_events',
#   'ipykernel.jupyter_core',
#   'dateutil.re',
#   'prompt_toolkit.key_binding.bindings.__future__',
#   'traitlets.config.ast',
#   'multiprocessing.sys',
#   'ipykernel.uuid',
#   'ipywidgets.widgets.widget_button',
#   'ipywidgets.IPython',
#   'pygments.filter',
#   'email.Errors',
#   'IPython.utils.locale',
#   'ctypes.sys',
#   'IPython.core.magics.config',
#   'pygments.lexers.__future__',
#   'posixpath',
#   'jupyter_client.channels',
#   'pkg_resources._vendor.packaging._compat',
#   'email.cStringIO',
#   'IPython.utils._sysinfo',
#   'prompt_toolkit.filters.cli',
#   'traitlets.logging',
#   'colorama.contextlib',
#   'zmq.utils.os',
#   'types',
#   'zmq.backend.cython._device',
#   'prompt_toolkit.utils',
#   'prompt_toolkit.clipboard.in_memory',
#   'IPython.core.linecache',
#   'ipywidgets.widgets.widget_string',
#   '_win32sysloader',
#   'json._json',
#   'ipykernel.jupyter_client',
#   '_codecs',
#   'traitlets.contextlib',
#   'ipykernel.comm.sys',
#   'IPython.core.unicodedata',
#   'enum.collections',
#   'json.sys',
#   'win32com.win32api',
#   'IPython.utils.os',
#   'IPython.extensions.inspect',
#   'concurrent.futures.multiprocessing',
#   'pygments.time',
#   'zmq.eventloop.ioloop',
#   'copy',
#   'ipykernel.datetime',
#   'prompt_toolkit.styles.collections',
#   'ipykernel.comm.logging',
#   'ipython_genutils.shutil',
#   'hashlib',
#   'prompt_toolkit',
#   'email.errors',
#   'keyword',
#   'ipython_genutils.random',
#   'pkg_resources._vendor.packaging',
#   'IPython.extensions.IPython',
#   'ipywidgets.widgets.sys',
#   'IPython.core.hashlib',
#   'ipywidgets.widgets.widget_output',
#   'pygments.lexers.fnmatch',
#   'prompt_toolkit.terminal.ctypes',
#   'IPython.utils.generics',
#   'ipykernel.connect',
#   'backports.shutil_get_terminal_size.os',
#   'prompt_toolkit.layout.collections',
#   'sre_compile',
#   'ipykernel',
#   '_hashlib',
#   'prompt_toolkit.layout.utils',
#   'IPython.utils.ulinecache',
#   'zmq.eventloop.cPickle',
#   'IPython.core.magics.code',
#   'IPython.core.sqlite3',
#   'IPython.core.bdb',
#   'logging.collections',
#   'IPython.core.threading',
#   'email.base64',
#   'pygments.__future__',
#   '__main__',
#   'colorama.initialise',
#   'multiprocessing.atexit',
#   'ipykernel.itertools',
#   'zmq.backend.cython.message',
#   'prompt_toolkit.string',
#   'prompt_toolkit.layout.re',
#   'IPython.extensions.textwrap',
#   'prompt_toolkit.layout.__future__',
#   'ipykernel.binascii',
#   'dateutil.parser',
#   'prompt_toolkit.token',
#   'IPython.utils.terminal',
#   'jupyter_client.ipython_genutils',
#   'encodings.codecs',
#   'ipywidgets.widgets.widget_selection',
#   'ipywidgets',
#   'IPython.utils.__builtin__',
#   'IPython.terminal.os',
#   'IPython.lib.threading',
#   'zmq.utils.jsonapi',
#   'email.MIMEMultipart',
#   'pkg_resources._vendor.win32com',
#   'ipywidgets.widgets.datetime',
#   'IPython.core.completer',
#   'ipykernel.base64',
#   '_ssl',
#   'ipykernel.types',
#   'IPython.utils.sys',
#   'IPython.utils.re',
#   'tornado',
#   'IPython.lib.clipboard',
#   'encodings.ascii',
#   'ipykernel.getpass',
#   'IPython.utils.inspect',
#   'zmq.backend.cython.sys',
#   'IPython.core.base64',
#   'pkg_resources.extern.appdirs',
#   'colorama',
#   '_sqlite3',
#   'ipython_genutils.text',
#   'IPython.core.shellapp',
#   'email.feedparser',
#   'email.MIMEBase',
#   'prompt_toolkit.selection',
#   'plistlib',
#   'multiprocessing._multiprocessing',
#   'concurrent.futures.sys',
#   'pygments.modeline',
#   'pkg_resources._vendor.collections',
#   'IPython.utils.wildcard',
#   'IPython.core.extensions',
#   'IPython.utils.tokenutil',
#   '_io',
#   'linecache',
#   '_strptime',
#   'ipywidgets.widgets.trait_types',
#   'IPython.core.compilerop',
#   'ipykernel.comm',
#   'jupyter_client.zmq',
#   'hmac',
#   'tornado.platform.interface',
#   'scandir',
#   'prompt_toolkit.terminal.six',
#   'dateutil.collections',
#   'prompt_toolkit.key_binding.bindings.named_commands',
#   '_multiprocessing',
#   'ipywidgets.widgets.traitlets',
#   'IPython.core.magics.osm',
#   'jupyter_client.json',
#   'random',
#   '_bisect',
#   'zmq.sugar.context',
#   'subprocess',
#   'IPython.extensions.storemagic',
#   'prompt_toolkit.key_binding.weakref',
#   'prompt_toolkit.key_binding.vi_state',
#   'pygments.operator',
#   'logging.os',
#   'ctypes._endian',
#   'encodings.encodings',
#   'ipykernel.numbers',
#   'colorama.ansitowin32',
#   'pygments.formatters._mapping',
#   'logging.stat',
#   'email.time',
#   'importlib',
#   'prompt_toolkit.styles.from_pygments',
#   'IPython.core.magic',
#   'ipywidgets.widgets.ipython_genutils',
#   'zmq.utils.threading',
#   'IPython.utils.dir2',
#   '_json',
#   'prompt_toolkit.key_binding.bindings.basic',
#   'pkg_resources._vendor.warnings',
#   'ipykernel.logging',
#   'traitlets.config.argparse',
#   'ipython_genutils.importstring',
#   'jupyter_client.blocking.traitlets',
#   'logging.thread',
#   'cProfile',
#   'prompt_toolkit.styles.defaults',
#   'prompt_toolkit.buffer_mapping',
#   'prompt_toolkit.history',
#   'IPython.lib.re',
#   'pathlib2',
#   'pygments.sys',
#   'prompt_toolkit.styles',
#   'concurrent.futures.threading',
#   'zipfile',
#   'repr',
#   'ipykernel.traceback',
#   'ssl',
#   'traitlets.config.__future__',
#   'prompt_toolkit.reactive',
#   'ipywidgets.widgets.widget_image',
#   'ipython_genutils.platform',
#   'prompt_toolkit.terminal.msvcrt',
#   'ipywidgets.widgets.numbers',
#   '_lsprof',
#   'IPython.os',
#   'pygments.lexer',
#   'prompt_toolkit.completion',
#   'zmq.error',
#   'pkg_resources._vendor.weakref',
#   'dateutil.tz.operator',
#   'traitlets.config.collections',
#   'IPython.utils.hashlib',
#   'IPython.terminal.traitlets',
#   'bisect',
#   'traitlets.config',
#   'IPython.utils.IPython',
#   'email',
#   'pydoc',
#   'threading',
#   'prompt_toolkit.keys',
#   'IPython.core.prefilter',
#   'ipywidgets.widgets.widget_float',
#   'prompt_toolkit.styles.from_dict',
#   'pkg_resources._vendor.six.moves',
#   'pkg_resources._vendor.pyparsing',
#   'IPython.lib.datetime',
#   'ctypes.wintypes',
#   'jupyter_core.paths',
#   'IPython.core.events',
#   'email.Message',
#   'jupyter_client.blocking.sys',
#   'IPython.core.textwrap',
#   'locale',
#   'ipywidgets.widgets.widget_date',
#   'prompt_toolkit.document',
#   'atexit',
#   'email.quopriMIME',
#   'IPython.core.autocall',
#   'IPython.core.sys',
#   'ipykernel.serialize',
#   'calendar',
#   'ipykernel.comm.traitlets',
#   'IPython.utils.backports',
#   'IPython.core.magics.__future__',
#   'traitlets.sys',
#   'dateutil',
#   'traitlets.utils.bunch',
#   'backports.shutil_get_terminal_size.get_terminal_size',
#   'tornado.log',
#   'jupyter_client.managerabc',
#   'urllib',
#   'IPython.core.os',
#   'IPython.lib.io',
#   'pkg_resources.extern.packaging.version',
#   'pygments.StringIO',
#   'ipykernel.displayhook',
#   'pkg_resources._vendor.string',
#   'zmq.sys',
#   'ctypes.subprocess',
#   'prompt_toolkit.validation',
#   'zmq.backend.cython.struct',
#   'ipywidgets.widgets.collections',
#   'IPython.utils.path',
#   'ipywidgets.widgets.inspect',
#   'IPython.core.atexit',
#   'pygments.plugin',
#   'prompt_toolkit.layout.controls',
#   'zmq.utils',
#   'jupyter_client.localinterfaces',
#   'Queue',
#   'jupyter_client.shutil',
#   'ctypes',
#   'IPython.lib.collections',
#   'IPython.core.magics.re',
#   'IPython.utils._process_common',
#   'pickleshare',
#   'win32com.win32com',
#   'ipython_genutils.functools',
#   'traitlets.config.application',
#   'jupyter_client.socket',
#   'tornado.stack_context',
#   'ipykernel.atexit',
#   'prompt_toolkit.key_binding.bindings',
#   'prompt_toolkit.filters.base',
#   'itertools',
#   'dateutil.tz.win',
#   'opcode',
#   'colorama.sys',
#   'pstats',
#   'prompt_toolkit.key_binding.bindings.math',
#   'ipykernel.IPython',
#   'traitlets.config.six',
#   'pdb',
#   'IPython.terminal.shortcuts',
#   'IPython.core.magics.subprocess',
#   'IPython.terminal.signal',
#   'IPython.extensions.os',
#   'IPython.core.magics.atexit',
#   'six.moves',
#   'IPython.terminal.logging',
#   'zmq.errno',
#   'prompt_toolkit.key_binding.collections',
#   'IPython.testing',
#   'prompt_toolkit.renderer',
#   'sqlite3.datetime',
#   'zmq.sugar.socket',
#   'prompt_toolkit.key_binding.bindings.string',
#   'pygments.lexers.re',
#   'prompt_toolkit.shortcuts',
#   'pygments',
#   'logging.errno',
#   'win32com.pythoncom',
#   'dateutil.tz.copy',
#   'prompt_toolkit.signal',
#   'email.uu',
#   'prompt_toolkit.shlex',
#   'IPython.core.hooks',
#   'email.socket',
#   'IPython.display',
#   'pkgutil',
#   'IPython.core.tokenize',
#   'platform',
#   'zmq.backend',
#   'IPython.lib.__future__',
#   'IPython.utils.sentinel',
#   'ipykernel.tornado',
#   'IPython.core.magics.warnings',
#   'logging.struct',
#   'sre_constants',
#   'zmq.backend.os',
#   'json',
#   'pygments.styles.default',
#   'prompt_toolkit.filters.prompt_toolkit',
#   'jupyter_client.pprint',
#   'jupyter_client.jsonutil',
#   'pkg_resources._vendor.sre_constants',
#   'zmq.sugar.random',
#   'ipykernel.platform',
#   'IPython.lib.warnings',
#   'json.re',
#   'prompt_toolkit.sys',
#   'zmq.utils.itertools',
#   'prompt_toolkit.layout.lexers',
#   'zmq.eventloop',
#   'ipywidgets.widgets',
#   'pkg_resources._vendor.sys',
#   'email.utils',
#   'IPython.IPython',
#   'prompt_toolkit.application',
#   'zmq.sugar',
#   'nturl2path',
#   'logging.cPickle',
#   'IPython.core.completerlib',
#   'logging.socket',
#   'email.MIMENonMultipart',
#   'getpass',
#   'ipykernel.sys',
#   'dateutil.io',
#   'dateutil.tz.contextlib',
#   'prompt_toolkit.inspect',
#   'prompt_toolkit.functools',
#   'storemagic',
#   'wcwidth.table_zero',
#   'prompt_toolkit.textwrap',
#   'email.random',
#   'ipython_genutils.__builtin__',
#   'concurrent.futures.Queue',
#   'multiprocessing.weakref',
#   'jupyter_client.datetime',
#   'IPython.terminal.prompt_toolkit',
#   'jupyter_client.binascii',
#   'ipykernel.thread',
#   'json.decoder',
#   'traitlets.enum',
#   'logging.atexit',
#   'IPython.core.magics.os',
#   'ipykernel.kernelapp',
#   'pkg_resources._vendor.packaging.specifiers',
#   'tornado.platform.auto',
#   'pkg_resources._vendor.appdirs',
#   'IPython.utils.linecache',
#   'site',
#   'pkg_resources',
#   'ipywidgets.widgets.widget_selectioncontainer',
#   'IPython.core.shutil',
#   'dateutil.tz',
#   'io',
#   'ipython_genutils.string',
#   'prompt_toolkit.search_state',
#   'pkg_resources._vendor.packaging._structures',
#   'IPython.core.pygments',
#   'shutil',
#   'IPython.utils.random',
#   'jupyter_client.clientabc',
#   'prompt_toolkit.clipboard.collections',
#   'pygments.filters.pygments',
#   'zmq.sugar.zmq',
#   'zmq.backend.sys',
#   'prompt_toolkit.terminal.os',
#   'prompt_toolkit.styles.base',
#   'IPython.lib.logging',
#   'ipykernel.zmqshell',
#   'IPython.utils.decorators',
#   'IPython.testing.skipdoctest',
#   'email.binascii',
#   'IPython.core.magics.script',
#   'sqlite3',
#   'pygments.formatters.pygments',
#   'prompt_toolkit.weakref',
#   'IPython.core.magics.basic',
#   'pkg_resources.extern',
#   'traitlets.config.traitlets',
#   'IPython.core.macro',
#   'ipywidgets.widgets.widget_style',
#   'IPython.core.magics.pprint',
#   'IPython.utils.data',
#   'dateutil.time',
#   'json.json',
#   'IPython.core.types',
#   'sys',
#   'IPython.terminal.IPython',
#   'multiprocessing.subprocess',
#   'IPython.core.string',
#   'ipykernel.re',
#   'email.Header',
#   'jupyter_client.traitlets',
#   'tornado.util',
#   'prompt_toolkit.terminal.sys',
#   'prompt_toolkit.bisect',
#   'dateutil.string',
#   'prompt_toolkit.output',
#   '_weakref',
#   'pygments.formatters.__future__',
#   'IPython.core.inputtransformer',
#   'pkg_resources.extern.pyparsing',
#   'urlparse',
#   'jupyter_client.dateutil',
#   'prompt_toolkit.key_binding.prompt_toolkit',
#   'pygments.cStringIO',
#   'ipywidgets.widgets.re',
#   'IPython.core.decorator',
#   'IPython.core.application',
#   'ipykernel._version',
#   'IPython.core',
#   'prompt_toolkit.layout.processors',
#   'IPython.core.pprint',
#   'traitlets.utils.six',
#   'logging.logging',
#   'prompt_toolkit.key_binding.registry',
#   'heapq',
#   'concurrent.futures._base',
#   'concurrent.futures',
#   'IPython.core.time',
#   'prompt_toolkit.terminal.array',
#   'prompt_toolkit.key_binding.bindings.completion',
#   'IPython.extensions',
#   'ipykernel.pickleutil',
#   'prompt_toolkit.key_binding.defaults',
#   'zmq.backend.cython.socket',
#   'select',
#   'IPython.terminal.pt_inputhooks.os',
#   'IPython.core.oinspect',
#   'pkg_resources.extern.packaging',
#   'zmq.sugar.time',
#   'prompt_toolkit.key_binding.bindings.codecs',
#   'zmq.sugar.attrsettr',
#   'email.mime',
#   'msvcrt',
#   'zmq.backend.cython.constants',
#   'ipython_genutils.path',
#   'IPython.utils._signatures',
#   'jupyter_client.logging',
#   'struct',
#   'IPython.utils.strdispatch',
#   'IPython.core.inputsplitter',
#   'IPython.utils.tokenize2',
#   'prompt_toolkit.terminal.errno',
#   'IPython.lib',
#   'sqlite3._sqlite3',
#   'prompt_toolkit.key_binding',
#   'IPython.utils.string',
#   'collections',
#   'jupyter_client.cPickle',
#   'prompt_toolkit.eventloop.six',
#   'prompt_toolkit.filters.collections',
#   'zmq.sugar.atexit',
#   'email.Parser',
#   'ipykernel.comm.comm',
#   'IPython.extensions.sys',
#   'backports.shutil_get_terminal_size.ctypes',
#   'traitlets.utils',
#   'ipython_genutils.encoding',
#   'dateutil.tz._common',
#   'zipimport',
#   'IPython.core.struct',
#   'zmq.ctypes',
#   'IPython.core.magics.execution',
#   'pkg_resources.extern.sys',
#   'pkg_resources.extern.packaging.markers',
#   'jupyter_client',
#   'IPython.terminal.magics',
#   'textwrap',
#   'zmq.platform',
#   'IPython.lib.subprocess',
#   'pkg_resources._vendor.threading',
#   'IPython.core.codeop',
#   'jupyter_client.channelsabc',
#   'prompt_toolkit.filters.__future__',
#   'jupyter_client.blocking.zmq',
#   'traitlets.config.re',
#   'zmq.backend.cython._version',
#   'multiprocessing.multiprocessing',
#   'IPython.lib.random',
#   'ipykernel.codeutil',
#   'IPython.utils.frame',
#   'signal',
#   'IPython.core.payloadpage',
#   'prompt_toolkit.terminal.prompt_toolkit',
#   'prompt_toolkit.filters.abc',
#   'prompt_toolkit.re',
#   'IPython.terminal.warnings',
#   'prompt_toolkit.win32_types',
#   'prompt_toolkit.layout.containers',
#   'quopri',
#   'IPython.core.magics',
#   'pygments.lexers.types',
#   'zmq.eventloop.zmqstream',
#   'IPython.core.getopt',
#   'jupyter_client.kernelspec',
#   'IPython.lib.display',
#   'ipywidgets._version',
#   'email.charset',
#   'IPython.terminal.prompts',
#   'mimetypes',
#   'IPython.core.magics.auto',
#   'traitlets.log',
#   'dateutil.tz.sys',
#   'ipykernel.io',
#   '_winreg',
#   'prompt_toolkit.key_binding.bindings.emacs',
#   'pygments.lexers._mapping',
#   'IPython.utils.token',
#   'email.Generator',
#   'IPython.utils.module_paths',
#   'pygments.lexers.os',
#   'logging.re',
#   'logging.traceback',
#   'IPython.core.magic_arguments',
#   'pygments.codecs',
#   'traitlets.utils.getargspec',
#   'pkg_resources._vendor.traceback',
#   'wcwidth.table_wide',
#   'warnings',
#   'IPython.utils.sysinfo',
#   'backports',
#   'ipywidgets.widgets.valuewidget',
#   'IPython.core.argparse',
#   'IPython.lib.security',
#   'email.encoders',
#   'win32com.imp',
#   'IPython.core.magics.traitlets',
#   'pkg_resources._vendor.re',
#   'pygments.formatters.re',
#   'tornado.escape',
#   'traitlets.config.logging',
#   'ipython_genutils.warnings',
#   'IPython.utils.subprocess',
#   'zmq.eventloop.__future__',
#   'jupyter_client.abc',
#   'prompt_toolkit.key_binding.bindings.itertools',
#   ...],
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x46474e0>}

# %%
mds['bson']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-968eace7ae99> in <module>()
# ----> 1 mds['bson']
#
# KeyError: 'bson'

# %%
import bson
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-06b0a290ed7c> in <module>()
# ----> 1 import bson
#
# ImportError: No module named bson

# %%
mds['pprint']
# Out:
# <module 'pprint' from 'C:\Anaconda2\lib\pprint.pyc'>

# %%
globals()['pprint'] = mds['pprint']

# %%
pprint
# Out:
# <module 'pprint' from 'C:\Anaconda2\lib\pprint.pyc'>
